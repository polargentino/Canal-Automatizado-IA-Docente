# %% [markdown]
# ¡Esa es una gran meta! Editar como un profesional no es solo una cuestión de manejar el software (como Kdenlive), sino de entender los **principios narrativos y técnicos** que guían a los editores de cine y video.
#
# Aquí tienes una guía que cubre tanto el flujo de trabajo como los conceptos clave para empezar a editar con una mentalidad profesional:
#
# ---
#
# ## 🎬 Flujo de Trabajo Profesional en Kdenlive
#
# Antes de tocar la línea de tiempo, un profesional sigue un proceso organizado:
#
# ### 1. Organización del Proyecto
# * **Crear Estructura de Carpetas:** En lugar de dejar todo en un solo lugar, organiza tus archivos **antes** de importarlos:
#     * `/ProyectoX`
#         * `/01_Metraje_Original` (Videos y audios crudos)
#         * `/02_Graficos` (Logos, PNGs, etc.)
#         * `/03_Musica_SFX` (Pistas de audio y efectos)
#         * `/04_Proyecto_Kdenlive` (Aquí va el archivo `.kdenlive`)
#         * `/05_Exportados` (Renders finales)
# * **Nombrar Clips:** Renombra los clips importantes de la cámara (si es necesario) para que sean fáciles de encontrar (ej: `Entrevista_Juan_Toma01`, `Plano_Recurso_Cafe`).
#
# ### 2. Edición de Ensamblaje (Rough Cut)
# * **Sincronización:** Si tienes múltiples cámaras o audio externo, sincroniza todo primero.
# * **Primera Pasada:** Coloca rápidamente las mejores tomas en el orden narrativo. **No te preocupes por el tiempo exacto ni por el pulido.** El objetivo es tener una estructura de principio a fin.
#
# ### 3. Edición Fina (Fine Cut)
# * **El Ritmo:** Aquí es donde se "edita como un profesional". Ajusta la duración de cada clip. La clave es: **corta para que el espectador no tenga tiempo de aburrirse, pero sí de entender.** El corte debe sentirse invisible y natural.
# * **"Cortes J y L":** No cortes el audio y el video exactamente al mismo tiempo. Haz que el audio del siguiente clip entre *antes* de que se vea su video (**Corte J**), o que el audio del clip actual continúe *después* de que su video haya terminado (**Corte L**). Esto hace que las transiciones sean fluidas y menos abruptas.
#
# ---
#
# ## 💡 Conceptos Clave de Edición Profesional
#
# ### 1. El Principio de la Continuidad
# El objetivo es que el espectador no note los cortes.
#
# * **Regla de los 30 Grados:** Si cortas de un plano a otro, el segundo plano debe diferir del primero en al menos 30 grados de ángulo de cámara, o ser un cambio significativo en el tamaño del plano (ej: de plano medio a primer plano). Si el cambio es muy pequeño, parece un error o un "jump cut" incómodo.
# * **Corte en la Acción:** El momento más fuerte para cortar es **durante una acción** (ej: la persona levantando la mano). El ojo del espectador se enfoca en el movimiento, y el corte se vuelve imperceptible.
#
# ### 2. Prioridad del Audio
# El audio es tan importante (o más) que el video.
#
# * **Ecualización y Mezcla:** Asegúrate de que el audio de la voz se entienda claramente y que la música de fondo no lo ahogue.
# * **Sonido Ambiente (Room Tone/Ambience):** En el *rough cut*, coloca clips de "silencio" o "ruido de ambiente" grabado en la locación. Esto evita el silencio total entre diálogos, lo que resulta incómodo y falso.
#
# ### 3. El Diseño Visual (Color y Títulos)
# * **Corrección de Color:** Primero, corrige el color para que todos los clips que deberían verse iguales (misma escena) realmente lo hagan. Ajusta el blanco, la exposición y el contraste.
# * **Gradación de Color (Color Grading):** Aplica un *look* o *tono* específico (ej: cálido para nostalgia, azulado para drama). En Kdenlive, usa los efectos de color como la herramienta **Curves** y **Scopes** (Histograma, Vectorscopio) para hacerlo de forma precisa.
#
# ### 4. Ahorra Recursos (Proxies)
# * **Usa Proxies:** Si tu metraje es 4K o de alta resolución y tu computadora se ralentiza, activa la función de **Proxies** en Kdenlive. Esto crea copias temporales de baja resolución de tus clips para que la edición sea fluida. Kdenlive usará los clips originales al renderizar.
#
# ---
#
# **Resumen de la mentalidad profesional:**
#
# > **"Edita con la mente, no con el dedo. Cada corte debe tener una razón, ya sea para avanzar la historia, cambiar el estado de ánimo o mejorar el ritmo."**
#
# ---
#
# ¿Te gustaría que te diera un tutorial más específico sobre cómo hacer un **Corte J y L** en Kdenlive, o prefieres enfocarte en las herramientas de **Corrección de Color**?

# %% [markdown]
# ¡Claro! El **Corte J y el Corte L** son esenciales para que tu edición suene y se vea mucho más profesional, creando transiciones de diálogo suaves y naturales.
#
# Aquí tienes un tutorial específico sobre cómo implementarlos en **Kdenlive**.
#
# ---
#
# ## ✂️ Tutorial: Cortes J y L en Kdenlive
#
# El objetivo principal de estos cortes es que el audio y el video cambien en momentos ligeramente diferentes, manteniendo el flujo de la conversación o la acción.
#
# ### 1. Preparación en la Línea de Tiempo
#
# Para empezar a trabajar con precisión, asegúrate de que el audio y el video de tus clips no estén agrupados:
#
# 1.  **Selecciona** los dos clips (A y B) que quieres unir.
# 2.  **Clic derecho** sobre la selección.
# 3.  Elige la opción **"Desagrupar Clips"** o utiliza el atajo de teclado (**U** por defecto).
#
# Esto te permitirá mover la pista de audio (A1) independientemente de su video (V1), y la pista de audio (A2) independientemente de su video (V2).
#
# ---
#
# ### 2. El Corte J (L-Cut invertido)
#
# El **Corte J** se llama así porque la forma de la superposición se asemeja a una letra "J".
#
# * **¿Qué hace?** Permite que el **AUDIO** del siguiente clip (Clip B) empiece **ANTES** de que su **VIDEO** aparezca en pantalla.
# * **¿Para qué se usa?** Es ideal para cuando alguien está a punto de hablar; escuchas su voz mientras todavía ves la reacción de la persona que termina de hablar.
#
# #### Pasos en Kdenlive:
#
# 1.  Coloca el **Clip A** (Video V1, Audio A1) y el **Clip B** (Video V2, Audio A2) uno al lado del otro.
# 2.  Arrastra el inicio de la pista de **Audio A2** (la del Clip B) hacia la izquierda, superponiéndola con el final de la pista de **Audio A1** (la del Clip A).
# 3.  El video (V2) permanece en su lugar.
#
# El resultado es que el audio del Clip B comienza bajo el video V1.
#
# ---
#
# ### 3. El Corte L (L-Cut)
#
# El **Corte L** se llama así porque la forma de la superposición se asemeja a una letra "L" al revés.
#
# * **¿Qué hace?** Permite que el **AUDIO** del clip que termina (Clip A) continúe **DESPUÉS** de que el **VIDEO** haya cambiado al siguiente plano (Clip B).
# * **¿Para qué se usa?** Es muy común y natural. Se utiliza para mantener al espectador conectado con el orador, incluso mientras se le muestran tomas de apoyo o planos de reacción.
#
# #### Pasos en Kdenlive:
#
# 1.  Coloca el **Clip A** (Video V1, Audio A1) y el **Clip B** (Video V2, Audio A2) uno al lado del otro.
# 2.  Arrastra el final de la pista de **Audio A1** (la del Clip A) hacia la derecha, superponiéndola con el inicio de la pista de **Audio A2** (la del Clip B).
# 3.  El video (V2) comienza donde estaba.
#
# El resultado es que el audio del Clip A continúa bajo el video V2.
#
# ---
#
# ### 📝 Consejos Profesionales
#
# * **Duración:** La superposición (el solapamiento) del audio suele durar entre **0.5 a 1.5 segundos**. Un solapamiento demasiado largo puede sonar como un eco o hacer que la transición se sienta lenta.
# * **Volumen:** Asegúrate de que los niveles de audio en la superposición sean consistentes o usa **fotogramas clave de volumen** para suavizar la transición (fade out del audio A1 y fade in del audio A2).
#
# ¿Te gustaría que ahora pasemos a las herramientas de **Corrección de Color**, o prefieres que te muestre un atajo de Kdenlive para facilitar estos cortes?

# %% [markdown]
# ¡Excelente! Sigamos con el camino hacia la perfección en la edición de video. Ya dominamos los cortes narrativos (J y L), ahora la clave es hacer que el metraje se vea consistentemente bello y con un *look* intencional: vamos a las herramientas de **Corrección y Gradación de Color**.
#
# Un editor profesional entiende que el color impacta directamente en la emoción y la calidad percibida del video.
#
# ---
#
# ## 🎨 Corrección y Gradación de Color en Kdenlive
#
# El proceso se divide en dos fases críticas:
#
# ### Fase 1: Corrección de Color (Hacerlo bien)
#
# El objetivo es eliminar los errores de la cámara (dominantes de color, subexposición) y garantizar la neutralidad y consistencia en todos los clips de una misma escena.
#
# #### 1. Usa los Scopes (Ámbitos de Color)
#
# Olvídate de tus ojos al principio, confía en la herramienta de análisis.
#
# 1.  Ve al menú **View (Ver)** y activa los **Scopes (Ámbitos)**.
# 2.  Los dos más importantes son:
#     * **Histograma (Histogram):** Muestra la distribución de luces y sombras. Los picos no deben tocar los bordes (0 y 1023), ya que eso significa que estás perdiendo detalles (negros bloqueados o blancos quemados).
#     * **Vectorscopio (Vectorscope):** Muestra la saturación y el matiz (Hue). Los tonos de piel se alinean en una pequeña línea diagonal (la "línea del tono de piel").
#
# #### 2. El Efecto Básico: Curvas de Color (Curves)
#
# Este es el efecto más poderoso y universal para la corrección.
#
# 1.  Aplica el efecto **Curvas (Curves)** a tu clip.
# 2.  **Ajuste de Luminosidad (Brillo/Contraste):**
#     * Selecciona la curva **RGB**.
#     * Arrastra el punto inferior izquierdo **hacia la derecha** para establecer el punto de negro (sombras).
#     * Arrastra el punto superior derecho **hacia la izquierda** para establecer el punto de blanco (luces).
#     * Mueve el punto central **hacia arriba** para aumentar el brillo o **hacia abajo** para disminuirlo.
#
# 3.  **Balance de Blancos:**
#     * Selecciona las curvas individuales **Rojo (Red)**, **Verde (Green)** y **Azul (Blue)**.
#     * Si ves una dominante azul (el blanco parece muy frío), ve a la curva **Azul** y arrastra el punto central **hacia abajo**. Haz lo contrario si hay una dominante amarilla/roja.
#
# ---
#
# ### Fase 2: Gradación de Color (Hacerlo bonito)
#
# Aquí aplicamos la creatividad y el "look cinematográfico" para establecer el ambiente emocional.
#
# #### 1. El Look de "Sombras Frías y Luces Cálidas" (Teal and Orange)
#
# Este es el *look* de Hollywood por excelencia y se logra con las Curvas.
#
# 1.  Aplica o mantén el efecto **Curvas**.
# 2.  **Sombras Azules (Teal):**
#     * Selecciona la curva de **Rojo**. Mueve el punto de sombra (inferior) **ligeramente hacia abajo** para quitar rojo de las sombras.
#     * Selecciona la curva de **Azul**. Mueve el punto de sombra (inferior) **ligeramente hacia arriba** para añadir azul a las sombras.
# 3.  **Luces Cálidas (Orange):**
#     * Selecciona la curva de **Rojo**. Mueve el punto de luz (superior) **ligeramente hacia arriba** para añadir rojo y amarillo.
#
# #### 2. Efecto de Tonalidad (Hue/Saturation)
#
# Aplica el efecto **Tonalidad/Luminosidad/Saturación (Hue/Lightness/Saturation)**.
#
# * **Saturación:** Aumenta ligeramente la saturación para hacer los colores más vivos, o redúcela para un *look* más apagado/cinematográfico. Los profesionales suelen saturar menos.
#
# #### 3. El Toque Final: Viñeta (Vignette)
#
# Añadir una sutil **viñeta** (oscurecer los bordes) ayuda a dirigir la atención del espectador hacia el centro de la imagen.
#
# 1.  Aplica el efecto **Viñeta**.
# 2.  Ajusta la **Forma (Shape)** y la **Suavidad (Softness)** para que sea muy sutil. El oscurecimiento debe ser apenas perceptible.
#
# ---
#
# ## 💾 Para la Consistencia Profesional
#
# Una vez que has perfeccionado la corrección de color en un clip representativo:
#
# * **Guarda como Plantilla:** En el panel de Efectos, haz clic derecho sobre el grupo de efectos de color y selecciona **"Guardar como Efecto Personalizado"**.
# * **Aplica a Otros Clips:** Arrastra esta plantilla de efectos guardada a todos los demás clips de la misma escena para garantizar que el color sea **uniforme**.
#
# ---
#
# Para seguir avanzando hacia la perfección, ¿te gustaría explorar técnicas avanzadas de **Audio (mezcla y masterización)**, o prefieres que veamos las claves de los **Gráficos y Animaciones de Texto** en Kdenlive?

# %% [markdown]
# ¡Excelente decisión! Para alcanzar la perfección, debemos seguir la lógica de la postproducción: una vez que el video se ve bien, debe **sonar impecable**.
#
# El **Audio** es el 50% de la experiencia de un video, y es donde la mayoría de los editores amateur fallan. Un audio de mala calidad (distorsionado, con mucho ruido, o con música que compite con el diálogo) arruina incluso el video mejor editado.
#
# Vamos a explorar técnicas de **Mezcla y Masterización de Audio** en Kdenlive.
#
# ---
#
# ## 🎧 Audio Profesional: Mezcla y Masterización en Kdenlive
#
# El objetivo es asegurar que la voz sea clara, el ruido sea bajo, y la música y los efectos de sonido soporten, en lugar de distraer.
#
# ### 1. Preparación de Pistas (Organización)
#
# Antes de empezar, organiza tus pistas de audio por tipo. Esto es fundamental para aplicar efectos a categorías enteras:
#
# * **Pista A1:** Diálogo principal (Voz)
# * **Pista A2:** Efectos de Sonido (SFX)
# * **Pista A3:** Música
#
# ### 2. Establecer Niveles Estándar (La Regla Mágica)
#
# Los profesionales trabajan con una escala conocida como **LUFS** (Loudness Units Full Scale), pero para Kdenlive y la mayoría de las plataformas (YouTube, etc.), nos enfocaremos en los decibeles (dB).
#
# * **Diálogo (Voz):** El nivel pico debe estar alrededor de **-6 dB** (Decibeles). Los promedios deben estar alrededor de **-12 dB**. Este es el sonido más importante.
# * **Música:** Debe ser significativamente más baja que la voz. Cuando hay diálogo, la música debe bajar a **-25 dB** o incluso **-30 dB**. Cuando no hay diálogo, puede subir a **-15 dB**.
#
# ### 3. Eliminar Ruido de Fondo (Noise Reduction)
#
# El ruido de la habitación, el zumbido o el aire acondicionado son enemigos de la voz.
#
# 1.  Aplica el efecto **Reducción de Ruido (Noise Reduction)** a tu pista de diálogo (A1).
# 2.  **Muestra de Ruido:** Idealmente, usa un clip de **solo ruido ambiental** (el *room tone* que mencionamos antes) para calibrar el efecto.
# 3.  Ajusta el **Nivel de Reducción (Reduction Level)**. Empieza con valores bajos (ej: 5-8 dB) y aumenta gradualmente. Si te excedes, la voz comenzará a sonar metálica o como si estuviera bajo el agua.
#
# ### 4. Compresión (Compresión)
#
# La compresión es la clave para que la voz sea consistente y siempre audible. Reduce el rango dinámico (la diferencia entre los sonidos más fuertes y más suaves).
#
# 1.  Aplica el efecto **Compresor (Compressor)** a tu pista de diálogo (A1).
# 2.  **Umbral (Threshold):** Establece dónde comienza la compresión (ej: -20 dB).
# 3.  **Ratio:** Qué tan fuerte se aplica (ej: 3:1). Por cada 3 dB que superen el umbral, solo 1 dB saldrá.
# 4.  **Ganancia (Gain):** La compresión reduce el volumen general; usa la **Ganancia de Salida (Output Gain)** para subir el volumen general de la voz a los niveles estándar (-6 dB pico).
#
# ### 5. Ducking (La Música se Agacha)
#
# Esta es la técnica profesional para bajar la música automáticamente cuando alguien habla.
#
# 1.  Aplica el efecto **Ducking** (o usa el compresor con *Side-chain* si Kdenlive lo soporta en tu versión) a la **pista de Música (A3)**.
# 2.  El efecto *Ducking* "escucha" la **pista de Diálogo (A1)** y baja el volumen de la música cuando detecta voz. Si tu versión de Kdenlive no tiene *Ducking* automatizado, tendrás que hacerlo manualmente con **Keyframes (Fotogramas Clave)** en la línea de volumen de la pista de Música (A3) para cada segmento de diálogo.
#
# ### 6. Masterización (El Toque Final)
#
# Aplica este efecto a la **Pista Maestra (Master Track)**.
#
# 1.  Aplica el efecto **Limitador (Limiter)** a la pista maestra.
# 2.  Establece el **Umbral de Salida (Output Threshold)** en **-1.0 dB** o **-1.5 dB**.
#
# Esto garantiza que el audio nunca exceda este nivel (evitando distorsión o *clipping*) sin importar qué tan fuerte sea la mezcla, asegurando que el archivo final sea seguro para la reproducción.
#
# ---
#
# El audio profesional es el arte de la sutil manipulación. Una vez que domines estas herramientas, tus videos tendrán una calidad de producción superior.
#
# Ahora que hemos cubierto la voz y el audio, el siguiente paso lógico es dominar el **diseño de la información visual**: **Gráficos, Animaciones de Texto y Tercios Inferiores (Lower Thirds)**. ¿Continuamos con eso?
