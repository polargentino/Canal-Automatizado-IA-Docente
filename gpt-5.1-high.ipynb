# %% [markdown]
# Aquí tienes un guion completo con los prompts estructurados en JSON, pensado para que Grok AI o Qwen AI generen los clips de forma coherente y luego tú los unas en Kdenlive.
#
# ```json
# {
#   "metadata": {
#     "title": "El Diario del Abuelo",
#     "language": "es",
#     "format": "video_short_film",
#     "estimated_total_duration_sec": 73,
#     "aspect_ratio": "16:9"
#   },
#   "global_style": {
#     "tone": "misterio, suspenso psicológico, sutilmente sobrenatural",
#     "visual_style": "realista, cinematográfico, alto contraste, atmósfera oscura e íntima",
#     "lighting": "interiores nocturnos, luz principal de una lámpara de mesa cálida, sombras profundas, algunos destellos fríos en el fondo",
#     "color_palette": "tonos cálidos (ámbar) cerca de la lámpara, sombras azuladas y grises en el fondo",
#     "camera_style": "planos medios y primeros planos, movimientos muy sutiles (ligero zoom in o respiración de cámara), profundidad de campo reducida",
#     "music_style": "cuerdas graves y pads ambientales muy suaves, sin melodía clara, énfasis en el silencio",
#     "continuity_rules": [
#       "El personaje principal, LUCAS, debe verse siempre como el mismo hombre joven: 25-30 años, tez clara u oliva, cabello corto castaño oscuro o negro, ligera barba de pocos días, complexión delgada.",
#       "Lucas viste siempre ropa sencilla y oscura: camiseta lisa y sudadera/chaqueta oscura, sin logotipos llamativos.",
#       "La habitación principal es la misma en todas las escenas de presente: mesa de madera, lámpara de mesa cálida, paredes oscuras, fondo en sombras.",
#       "El diario antiguo debe ser siempre el mismo objeto: grueso, tapas de cuero oscuro, aspecto muy usado, cierre sencillo (cinta o hebilla).",
#       "Mantener el mismo tipo de encuadres, color y contraste en todas las escenas de presente para que parezcan parte de la misma historia.",
#       "Solo la escena de recuerdo/flashback debe tener un tratamiento visual diferente (más lavado, ligeramente granulado, aspecto de memoria)."
#     ]
#   },
#   "character_profile": {
#     "lucas": {
#       "name": "Lucas",
#       "age": "25-30",
#       "description": "Hombre joven, rostro serio y preocupado, cabello corto castaño oscuro o negro, ligera barba de pocos días, complexión delgada.",
#       "wardrobe": "Camiseta lisa oscura (gris o negra) y sudadera o chaqueta también oscura, sin estampados llamativos.",
#       "typical_expression": "Preocupado, tenso, introspectivo, mirada fija y pensativa.",
#       "voice": "Grave, susurrante, tono contenido, como si temiera ser escuchado."
#     },
#     "abuelo": {
#       "name": "Abuelo de Lucas",
#       "age": "80+",
#       "description": "Hombre muy mayor, delgado, cabello blanco ralo, rostro muy arrugado, mirada cansada pero intensa.",
#       "presence": "Solo aparece claramente en la escena de flashback. En el presente se sugiere como una sombra o presencia difusa."
#     },
#     "diary": {
#       "description": "Diario antiguo, grueso, tapas de cuero oscuro agrietado, cantos amarillentos, páginas envejecidas, escritura a mano con tinta oscura, algunas páginas con símbolos o dibujos inquietantes."
#     }
#   },
#   "instructions_for_llm": "Este JSON describe una sola historia de misterio dividida en varias escenas. Cada escena es un clip de video que debe respetar la continuidad del personaje (Lucas), del diario y del ambiente. Utiliza el campo 'video_prompt' de cada escena como base para generar el prompt hacia el modelo de video, manteniendo el mismo estilo visual y de iluminación indicado en 'global_style'. Respeta el orden de las escenas para que la narración tenga sentido. No cambies la apariencia básica de Lucas ni del diario entre escenas. Las voces en off y diálogos están en español y deben sincronizarse aproximadamente con la duración de cada clip.",
#   "scenes": [
#     {
#       "id": "scene_01",
#       "title": "El legado",
#       "target_duration_sec": 5,
#       "timeline_position": 1,
#       "video_prompt": "Plano medio de un hombre joven llamado Lucas, de unos 25-30 años, rostro serio y preocupado, sentado a una mesa de madera en una habitación oscura. La única fuente de luz es una lámpara de mesa cálida que ilumina parcialmente su rostro, dejando el fondo en sombras profundas. Lucas mira el diario antiguo cerrado que está sobre la mesa frente a él. La cámara está casi fija, con un leve movimiento de respiración o un muy ligero zoom in hacia Lucas y el diario durante 5 segundos. Estilo realista, cinematográfico, alto contraste, atmósfera de misterio. Misma apariencia de Lucas en todas las futuras escenas.",
#       "voice_over": {
#         "text": "Mi abuelo me dejó este diario. Me dijo que no lo abriera...",
#         "voice_description": "Voz de Lucas grave, susurrante, íntima, ligeramente temblorosa.",
#         "approx_start_sec": 1,
#         "approx_end_sec": 4.5
#       },
#       "dialogue_on_screen": null,
#       "sound_design": {
#         "ambience": "Silencio denso de habitación nocturna, leve zumbido de la lámpara o ruido ambiente muy suave.",
#         "fx": "Sutil crujido de la silla o de la mesa cuando Lucas se mueve apenas.",
#         "music": "Nota grave muy sutil y sostenida, casi imperceptible."
#       },
#       "continuity_notes": "Establecer claramente la apariencia de Lucas, la mesa de madera, la lámpara y el diario. Esta escena marca el estilo visual base del resto de escenas de presente.",
#       "editing_suggestion": "Usar esta escena como apertura. Fundido desde negro en el primer fotograma, sin cortes internos."
#     },
#     {
#       "id": "scene_02",
#       "title": "La tentación",
#       "target_duration_sec": 7,
#       "timeline_position": 2,
#       "video_prompt": "Primer plano de las manos de Lucas sobre la mesa de madera. Una de sus manos se acerca lentamente al diario antiguo cerrado, dudando, sin llegar a tocarlo de inmediato. La lámpara de mesa, ligeramente fuera de foco al fondo, parpadea suavemente, creando pequeños cambios de luz sobre el cuero del diario. La habitación sigue oscura, fondo en sombras profundas. Cámara muy estable con leve acercamiento al diario y a las manos de Lucas durante 7 segundos. Estilo realista, mismo ambiente y mesa que en la escena 01.",
#       "voice_over": {
#         "text": "Pero los secretos no se heredan sin motivo.",
#         "voice_description": "Voz de Lucas grave, susurrante, tono reflexivo.",
#         "approx_start_sec": 2,
#         "approx_end_sec": 5
#       },
#       "dialogue_on_screen": null,
#       "sound_design": {
#         "ambience": "Mismo ambiente silencioso de habitación nocturna.",
#         "fx": "Leve chasquido eléctrico de la lámpara al parpadear, suave roce de la mano de Lucas con la madera al moverse.",
#         "music": "Textura ambiental muy tenue, pequeñas notas agudas muy discretas que aumentan la tensión."
#       },
#       "continuity_notes": "Mantener el mismo diario y misma iluminación cálida de la lámpara. Las manos deben corresponder a Lucas (joven, piel acorde a su apariencia).",
#       "editing_suggestion": "Corte directo desde la escena 01 al inicio de este primer plano para aumentar la sensación de intimidad y tensión."
#     },
#     {
#       "id": "scene_03",
#       "title": "El aviso",
#       "target_duration_sec": 8,
#       "timeline_position": 3,
#       "video_prompt": "Escena de recuerdo/flashback. Plano medio de Lucas adolescente (mismo tipo de rostro pero más joven) sentado al lado de la cama de un anciano muy mayor (el abuelo) en una habitación de hospital o cuarto muy modesto. El abuelo, débil, le entrega el mismo diario antiguo a Lucas, tomándole la mano con fuerza sorprendente. La luz es pálida, algo fría, entrando por una ventana; el estilo visual es ligeramente deslavado, con algo de grano, como memoria. La cámara se mueve muy lentamente hacia las manos que intercambian el diario durante 8 segundos.",
#       "voice_over": {
#         "text": "La última vez que lo vi, apenas podía hablar. Solo alcanzó a susurrar mi nombre... y señalar el diario.",
#         "voice_description": "Voz de Lucas adulta en off, grave y susurrante, cargada de culpa y nostalgia.",
#         "approx_start_sec": 1,
#         "approx_end_sec": 7
#       },
#       "dialogue_on_screen": {
#         "spoken_by": "Abuelo",
#         "text": "Lucas...",
#         "delivery_notes": "Voz muy débil, rota, casi un suspiro, solo una vez, cerca del final del clip."
#       },
#       "sound_design": {
#         "ambience": "Ambiente de cuarto silencioso, quizá un débil pitido de monitor o respiración asistida, muy bajo.",
#         "fx": "Suave crujido de la cama cuando el abuelo se mueve, roce del cuero del diario al ser entregado.",
#         "music": "Cuerda grave suave, nota sostenida que crece un poco cuando el abuelo le entrega el diario."
#       },
#       "continuity_notes": "El diario debe ser claramente el mismo objeto que en las escenas 01 y 02. Aquí se establece el origen del diario. No cambiar su aspecto.",
#       "editing_suggestion": "Introducir esta escena con un corte directo y, si se desea, un leve efecto de desvanecimiento al entrar y salir para marcar el recuerdo."
#     },
#     {
#       "id": "scene_04",
#       "title": "Decisión",
#       "target_duration_sec": 7,
#       "timeline_position": 4,
#       "video_prompt": "Regreso al presente. Primerísimo plano del rostro de Lucas adulto en la misma habitación oscura de las escenas 01 y 02. La luz cálida de la lámpara ilumina un lado de su cara, dejando el otro en sombra. Lucas mira hacia abajo, al diario, respira hondo, cierra los ojos un instante y luego, fuera de cuadro, abre el diario (se escucha el sonido). La cámara se aproxima lentamente a su rostro durante 7 segundos.",
#       "voice_over": {
#         "text": "Pensé que era solo una manía de anciano. Hasta hoy.",
#         "voice_description": "Voz de Lucas grave, susurrante, con un matiz de resignación.",
#         "approx_start_sec": 2,
#         "approx_end_sec": 6
#       },
#       "dialogue_on_screen": null,
#       "sound_design": {
#         "ambience": "Mismo ambiente silencioso del cuarto.",
#         "fx": "Sonido claro del cuero y las hojas del diario al abrirse, un suave suspiro de Lucas.",
#         "music": "Ligera subida de tensión con un pad oscuro justo en el momento en que se abre el diario."
#       },
#       "continuity_notes": "Misma ropa, misma iluminación y escenario que en las escenas 01 y 02. Es importante que el momento de apertura del diario se oiga claramente.",
#       "editing_suggestion": "Corte directo desde la escena 03 a este primer plano. Se puede enfatizar el sonido de abrir el diario para unir ambas líneas temporales."
#     },
#     {
#       "id": "scene_05",
#       "title": "La primera página",
#       "target_duration_sec": 8,
#       "timeline_position": 5,
#       "video_prompt": "Plano cenital o ligeramente inclinado sobre el diario abierto en la mesa de madera. Se ven páginas envejecidas, con escritura a mano en tinta oscura. La fecha escrita en la parte superior coincide con el día actual (sin necesidad de mostrar una fecha específica, solo que se intuya que es 'hoy'). En una de las páginas hay un pequeño dibujo esquemático de una lámpara de mesa y la silueta de un hombre sentado, similar a la situación actual de Lucas. Las manos de Lucas sostienen los bordes del diario. La lámpara ilumina las páginas con un tono cálido, mientras el fondo queda en penumbra. La cámara se acerca lentamente al texto y al dibujo durante 8 segundos.",
#       "voice_over": {
#         "text": "Escribió sobre mí... antes de que yo naciera.",
#         "voice_description": "Voz de Lucas en off, incrédula y asustada, pero aún en susurro.",
#         "approx_start_sec": 4,
#         "approx_end_sec": 7.5
#       },
#       "dialogue_on_screen": {
#         "spoken_by": "Lucas",
#         "text": "«Si estás leyendo esto, ya es tarde...»",
#         "delivery_notes": "Lucas lee en voz baja una línea del diario, como murmurando, entre los segundos 1.5 y 4."
#       },
#       "sound_design": {
#         "ambience": "Ambiente silencioso con el leve zumbido de la lámpara.",
#         "fx": "Suave crujido de las páginas al pasar ligeramente o ser tocadas.",
#         "music": "Pequeños golpes de notas agudas muy suaves cuando se ve el dibujo de la lámpara y la silueta del hombre."
#       },
#       "continuity_notes": "Mostrar claramente que el diario describe una escena igual a la actual. El texto puede ser poco legible, pero la idea debe sugerirse visualmente.",
#       "editing_suggestion": "Corte directo desde el rostro de Lucas (escena 04) a la vista de las páginas. Mantener el ritmo lento."
#     },
#     {
#       "id": "scene_06",
#       "title": "Ruidos en la casa",
#       "target_duration_sec": 7,
#       "timeline_position": 6,
#       "video_prompt": "Plano general o plano medio abierto de Lucas sentado a la mesa de madera, con el diario abierto frente a él. La habitación está oscura excepto por la lámpara cálida. Al fondo, se insinúa un pasillo o una puerta entreabierta en penumbra. Lucas levanta la mirada del diario, alerta, como si hubiera escuchado algo fuera de cuadro. La lámpara parpadea con más intensidad, proyectando sombras que se mueven ligeramente en las paredes. La cámara permanece casi fija, con un leve movimiento lateral muy suave durante 7 segundos.",
#       "voice_over": {
#         "text": "La casa empezó a sonar distinta. Como si no estuviéramos solos.",
#         "voice_description": "Voz de Lucas en off, susurrante, con tensión creciente.",
#         "approx_start_sec": 2,
#         "approx_end_sec": 6
#       },
#       "dialogue_on_screen": null,
#       "sound_design": {
#         "ambience": "Silencio de casa nocturna, se introduce un crujido lejano de madera o un golpe suave en otra habitación.",
#         "fx": "Parpadeo audible de la lámpara, respiración de Lucas algo más marcada.",
#         "music": "Aumento muy discreto de la tensión con capas de sonido graves, sin ritmo."
#       },
#       "continuity_notes": "La puerta o pasillo al fondo se puede reutilizar en escenas posteriores para reforzar la sensación de espacio continuo.",
#       "editing_suggestion": "Corte directo desde el plano del diario (escena 05). Permitir que el sonido del crujido o golpe distante sea el detonante del cambio de plano."
#     },
#     {
#       "id": "scene_07",
#       "title": "Susurros en las páginas",
#       "target_duration_sec": 8,
#       "timeline_position": 7,
#       "video_prompt": "Primer plano del diario abierto sobre la mesa. Una nueva página está llena de escritura apresurada, casi ilegible, con palabras y frases superpuestas. Entre todo el caos, una palabra se repite varias veces y destaca: 'ESCÚCHALOS'. La luz de la lámpara tiembla y parece que las sombras se mueven ligeramente sobre el papel. La cámara se acerca lentamente a la palabra repetida durante 8 segundos, mientras se insinúan leves sombras alrededor del borde del encuadre.",
#       "voice_over": {
#         "text": "Hay voces entre las líneas...",
#         "voice_description": "Voz de Lucas en off, casi un murmullo, con un tono de miedo contenido.",
#         "approx_start_sec": 3,
#         "approx_end_sec": 6.5
#       },
#       "dialogue_on_screen": null,
#       "sound_design": {
#         "ambience": "Ambiente silencioso de la habitación.",
#         "fx": "Susurros muy suaves e indistinguibles en segundo plano, como si vinieran del propio diario. Aumentan levemente y luego se apagan.",
#         "music": "Textura aguda muy sutil, como un zumbido de tensión que crece y se desvanece."
#       },
#       "continuity_notes": "La palabra 'ESCÚCHALOS' debe ser claramente legible en la página para el espectador, aunque el resto del texto sea caótico.",
#       "editing_suggestion": "Corte directo desde la escena 06. Sin transiciones elaboradas para mantener la tensión seca."
#     },
#     {
#       "id": "scene_08",
#       "title": "La sombra del abuelo",
#       "target_duration_sec": 8,
#       "timeline_position": 8,
#       "video_prompt": "Plano medio desde atrás y ligeramente de lado de Lucas, sentado frente a la mesa con el diario abierto. Vemos su silueta y la lámpara sobre la mesa. En el fondo oscuro de la habitación, en una esquina o cerca de la puerta, empieza a formarse lentamente una figura humana difusa, alta pero encorvada, semejante a la silueta del abuelo anciano. La figura nunca se ve con nitidez, permanece en penumbra. Lucas parece sentir la presencia: su espalda se tensa, gira lentamente la cabeza hacia la sombra, pero no se llega a mostrar su reacción completa. La cámara realiza un lento acercamiento que incluye tanto a Lucas como a la sombra al fondo durante 8 segundos.",
#       "voice_over": {
#         "text": "No quería creerlo. Pero reconocí esa respiración.",
#         "voice_description": "Voz de Lucas en off, grave, temerosa, aún en susurro.",
#         "approx_start_sec": 2.5,
#         "approx_end_sec": 7
#       },
#       "dialogue_on_screen": null,
#       "sound_design": {
#         "ambience": "Ambiente de habitación silenciosa, ahora con un leve sonido de respiración ajena, profunda y cansada, muy bajo pero distinguible.",
#         "fx": "Parpadeo de la lámpara, sutil crujido del suelo como si alguien se apoyara.",
#         "music": "Capa grave más intensa que en escenas anteriores, generando sensación de presencia."
#       },
#       "continuity_notes": "La silueta del abuelo debe recordar claramente al anciano de la escena 03, pero sin mostrar detalles del rostro. Mantener el misterio: no se ve claramente si es un fantasma o una sombra sugestiva.",
#       "editing_suggestion": "Corte directo desde el primer plano del diario (escena 07) a este plano más abierto para revelar el espacio y la presencia al fondo."
#     },
#     {
#       "id": "scene_09",
#       "title": "El pedido",
#       "target_duration_sec": 8,
#       "timeline_position": 9,
#       "video_prompt": "Primer plano del diario abierto. Mientras la cámara observa, sobre una página en blanco empiezan a aparecer lentamente palabras escritas como por una mano invisible: 'CIERRA ESTE DIARIO Y DÉJAME IR'. La tinta parece formarse sola, letra temblorosa pero clara. A los lados del encuadre, se sugieren las manos de Lucas temblando ligeramente, sin tocar el papel. La luz de la lámpara se estabiliza por un momento, enfocando el mensaje. La cámara se acerca progresivamente al texto durante los 8 segundos.",
#       "voice_over": {
#         "text": "Entendí, por fin, que el diario no era para mí. Era su cárcel.",
#         "voice_description": "Voz de Lucas en off, triste, con culpa, pero todavía en un tono controlado y susurrante.",
#         "approx_start_sec": 2,
#         "approx_end_sec": 7
#       },
#       "dialogue_on_screen": {
#         "spoken_by": "Lucas",
#         "text": "Lo siento, abuelo.",
#         "delivery_notes": "Lucas lo susurra casi sin voz, cerca del final del clip, entre los segundos 6 y 7.5."
#       },
#       "sound_design": {
#         "ambience": "Silencio casi absoluto, solo un muy suave zumbido de fondo.",
#         "fx": "Pequeño ruido húmedo o rasposo mientras las letras aparecen, como si la tinta fuese escribiéndose sola.",
#         "music": "Ligero cambio hacia una sensación más melancólica, sin dejar de ser tensa."
#       },
#       "continuity_notes": "El mensaje debe aparecer claramente en la página del diario, legible por el espectador. Conectar esto emocionalmente con el abuelo visto en la escena 03.",
#       "editing_suggestion": "Corte directo desde la escena 08. Se puede enfatizar el paso al primer plano para centrar la atención en el texto sobrenatural."
#     },
#     {
#       "id": "scene_10",
#       "title": "Cierre",
#       "target_duration_sec": 7,
#       "timeline_position": 10,
#       "video_prompt": "Plano medio de Lucas frente a la mesa en la habitación oscura, similar al de la escena 01. Lucas, con el rostro serio y afectado, cierra el diario con decisión, produciendo un sonido claro. Tras cerrarlo, la lámpara deja de parpadear y se estabiliza unos instantes, iluminando el rostro de Lucas con una luz más firme. Después de un segundo de calma, la lámpara se apaga sola lentamente, sumiendo la habitación en la oscuridad total al final del clip. La cámara permanece casi fija, con un muy ligero zoom out de 7 segundos.",
#       "voice_over": {
#         "text": "Algunos secretos no son para nosotros.",
#         "voice_description": "Voz de Lucas en off, grave, aceptando, aún en susurro pero más firme.",
#         "approx_start_sec": 2,
#         "approx_end_sec": 6
#       },
#       "dialogue_on_screen": null,
#       "sound_design": {
#         "ambience": "Mismo ambiente silencioso del inicio.",
#         "fx": "Sonido fuerte y claro al cerrar el diario, clic o leve chasquido de la lámpara al apagarse.",
#         "music": "Ligero descenso en la tensión, una nota grave que se desvanece en el silencio cuando la pantalla queda a oscuras."
#       },
#       "continuity_notes": "Cerrar visualmente el ciclo con un plano similar al de la escena 01, pero con Lucas cambiado emocionalmente. El apagado final de la lámpara es el cierre de la historia.",
#       "editing_suggestion": "Corte directo desde la escena 09. Terminar con fundido a negro sincronizado con el apagado de la lámpara si se desea."
#     }
#   ]
# }
# ```
