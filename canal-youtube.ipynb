# %% [markdown]
# ¡Perfecto! Documentar el proceso de esta manera, combinando la transcripción con la estructura pedagógica de Módulos y Tareas, hará que la replicación y la enseñanza sean mucho más efectivas.
#
# A continuación, tienes la transcripción estructurada en formato **Markdown** con encabezados y referencias de tiempo:
#
# ---
#
# ## 💻 Guía Completa: Canal de YouTube Automatizado con IA (Estructura Docente)
#
# Esta documentación sigue los **siete bloques** presentados en el video, enfocándose en la replicabilidad.
#
# ### 🎯 Introducción y Fundamentos
#
# * **Alcance del Proyecto:** Crear un canal de YouTube sin exponerse (sin aparecer en cámara), aprovechando las herramientas de Inteligencia Artificial (IA) gratuitas.
#     * **Referencia:** Canales como Alux, Blix, Relatos de la Noche, Magnates Media, que ganan grandes sumas por visualizaciones.
#     * **Tiempo:** \[0:01 - 0:44]
#
# ***
#
# ## ⚙️ Módulo 1: Configuración, Nicho y Branding del Canal
#
# Este módulo establece los cimientos del canal. La elección del nicho y el *branding* (marca) son cruciales para el crecimiento inicial.
#
# ### 📝 Tarea 1.1: Creación de la Cuenta de YouTube
#
# * **Acción:** Crear un nuevo canal de YouTube desde el menú de la foto de perfil, seleccionando "Ver todos los canales" y luego "Crear uno nuevo".
# * **Tiempo:** \[0:46 - 1:11]
#
# ### 📝 Tarea 1.2: Selección de un Nicho Verticalizado
#
# * **Concepto Clave:** Al inicio, el nicho debe ser muy **específico y verticalizado** para facilitar la diferenciación.
# * **Herramienta de IA:** Uso de un **GPT específico** para *brainstorming* (lluvia de ideas).
# * **Implementación con IA:**
#     1.  Ir a **ChatGPT** (versión gratuita) y buscar el GPT llamado **VidIQ**.
#     2.  Preguntar a VidIQ: "Dime **20 nichos virales** para crear un canal de YouTube".
#     3.  *(Ejemplo elegido en el video: Historias de Miedo)*
# * **Tiempo:** \[1:14 - 3:05]
#
# ### 📝 Tarea 1.3: Definición del Nombre y Descripción
#
# * **Herramienta de IA:** Continuar usando el **GPT de VidIQ**.
# * **Implementación:**
#     1.  Solicitar 10 nombres originales para el nicho elegido (Ej. Leyendas Macabras).
#     2.  Aplicar el nombre en la configuración de YouTube.
#     3.  Solicitar una pequeña descripción del canal al GPT y pegarla en la sección de **"Información Básica"** de YouTube Studio.
# * **Tiempo:** \[3:07 - 4:23]
#
# ### 📝 Tarea 1.4: Creación de Logo y Banner con IA
#
# * **Herramienta de IA:** **Kitel.so** (Ofrece resultados profesionales de forma sencilla).
# * **Pasos en Kitel:**
#     1.  Crear un nuevo proyecto y usar el **generador de logos por IA**.
#     2.  Usar un *prompt* (instrucción) que se adapte al nicho (Ej. "un logo de un zombie").
#     3.  **Para el Banner:** Crear un diseño con las dimensiones recomendadas por YouTube ($2560 \times 1440$ píxeles).
#     4.  **Tip Docente:** Usar una **plantilla de área segura** para asegurar que el diseño se vea bien en todos los dispositivos (móvil, tablet, PC).
#     5.  Descargar el archivo ZIP e insertarlo en la sección **"Marca"** de YouTube Studio.
# * **Tiempo:** \[4:24 - 7:09]
#
# ***
#
# ## 🎬 Módulo 2: Creación del Contenido Viral (Guion y Voz)
#
# Esta fase se enfoca en producir el material fuente (guion, audio y clips) para el video.
#
# ### 📝 Tarea 2.1: Creación del Guion (Script) Detallado
#
# * **Estrategia:** **Analizar canales populares** del nicho (no necesariamente los que tienen más seguidores, sino los que tienen muchas visitas en *todos* sus videos).
# * **Herramienta de IA:** **Harpa AI** (Extensión de Google Chrome con capacidad para leer el contenido de la web/video que se está viendo).
# * **Implementación:**
#     1.  Abrir un video viral de la competencia.
#     2.  Usar Harpa AI para pedirle un diálogo, especificando:
#         * Duración (Ej. 1 minuto).
#         * Número de escenas (Ej. 6 escenas).
#         * Solicitar una voz de narrador y la **descripción detallada** para generar las imágenes de IA de cada escena.
#     3.  Copiar y pegar el guion en un documento para revisión.
# * **Tiempo:** \[7:31 - 9:12]
#
# ### 📝 Tarea 2.2: Generación de Clips de Video por Escena
#
# * **Herramienta de IA:** **Bedo** (Generador gratuito de videos en segundos).
# * **Implementación:**
#     1.  Copiar la **descripción de la imagen/escena** generada por Harpa AI.
#     2.  Pegar la descripción en Bedo y generar el clip.
#     3.  Descargar y **enumerar** cada clip según la escena correspondiente (Ej. Escena 1, Escena 2, etc.).
# * **Tiempo:** \[9:14 - 9:53]
#
# ### 📝 Tarea 2.3: Generación de la Voz del Narrador (Audio)
#
# * **Herramienta de IA:** **ElevenLabs** (La mejor plataforma de síntesis de voz).
# * **Implementación:**
#     1.  Ir a la **"Voice Library"** (Librería de Voces).
#     2.  Filtrar por la categoría más adecuada (Ej. "Historia y Narración") y voces más utilizadas.
#     3.  Seleccionar una voz (Ej. Valentino) y añadirla a "Mis Voces".
#     4.  Copiar el texto del guion de la primera escena y pegarlo en el apartado **"Speech"**.
#     5.  Generar el audio y repetir el proceso para cada escena.
# * **Tiempo:** \[9:54 - 11:05]
#
# ***
#
# ## ✂️ Módulo 3: Edición y Publicación Final
#
# Esta etapa transforma los componentes individuales en el video final optimizado.
#
# ### 📝 Tarea 3.1: Edición del Video (Sincronización y Efectos)
#
# * **Software:** **CapCut** (Editor de video, aunque se puede usar cualquier otro).
# * **Pasos Clave:**
#     1.  Importar todos los clips de video y archivos de audio (narración).
#     2.  **Sincronización:** Arrastrar cada clip de video al inicio de su respectivo audio.
#     3.  **Ajuste de Duración:** Usar la función de **velocidad** de CapCut para estirar el clip de video (cámara lenta) hasta que su duración coincida con la duración del audio narrado.
#     4.  **Transiciones:** Aplicar una transición a todas las escenas.
#     5.  **Efectos Visuales:** Añadir un efecto general (Ej. *Black Noise* o *Retro*) y ajustar el color (*Customized adjustment*) para mantener la consistencia visual.
# * **Tiempo:** \[11:07 - 13:17]
#
# ### 📝 Tarea 3.2: Subtítulos Automáticos (Auto Caption)
#
# * **Propósito:** Mejorar la accesibilidad y la retención del espectador.
# * **Implementación:** Seleccionar todos los audios en CapCut y usar la opción **"Auto Caption"** (Subtítulos Automáticos).
# * **Personalización:** Editar la plantilla de los subtítulos para que sean visualmente atractivos.
# * **Tiempo:** \[13:17 - 13:42]
#
# ### 📝 Tarea 3.3: Creación y Validación de la Miniatura
#
# * **Estrategia:** La miniatura debe ser la base para la tasa de clics (CTR).
# * **Herramienta de IA:** **Kitel.so** (Usando la base del fotograma más impactante del video).
# * **Validación:** Usar una plataforma externa para validar si la miniatura **"resalta lo suficiente"** en comparación con otros videos recomendados.
# * **Tiempo:** \[13:44 - 14:57]
#
# ### 📝 Tarea 3.4: SEO y Publicación del Video
#
# * **Herramienta de IA:** Regresar al **GPT de VidIQ** para la optimización.
# * **Pasos en YouTube Studio:**
#     1.  Subir el video (Símbolo de Subida en el panel).
#     2.  **Título y Descripción:** Solicitar al GPT un título y una descripción, pegándole el diálogo completo del guion para que entienda el contexto.
#     3.  Subir la miniatura (Puede requerir verificación de teléfono).
#     4.  **Etiquetas (Tags):** Solicitar al GPT una lista de etiquetas adecuadas y pegarlas en la sección "Mostrar más".
#     5.  **Revisión Final:** Seleccionar la categoría (Ej. Entretenimiento) y verificar la ausencia de problemas de derechos de autor.
#     6.  **Publicación/Programación:** Publicar el video o programarlo para una fecha posterior.
# * **Tiempo:** \[14:57 - 17:02]
#
# ***
#
# ## 📈 Módulo 4: El Secreto del Éxito
#
# * **Clave:** El secreto para el éxito es la **consistencia** y **comenzar**. La IA elimina las barreras de entrada para el emprendimiento digital.
# * **Tiempo:** \[17:04 - 17:19]
