# %% [markdown]
# Este video del canal **AI en ACCIÓN** explica cómo utilizar la herramienta de inteligencia artificial **Mobiflow** para convertir texto en videos cinematográficos de alta calidad de forma gratuita y sin límites.
#
# Aquí tienes los puntos clave del tutorial:
#
# ### 📽️ ¿Qué es Mobiflow?
#
# Es una plataforma de IA muy versátil que permite generar trailers, películas, videoclips, contenido educativo y dibujos animados a partir de un simple prompt o guion [[05:34](http://www.youtube.com/watch?v=PIKqWKES9ME&t=334)]. La herramienta se encarga de todo: generación de personajes, ambientes y edición completa [[03:32](http://www.youtube.com/watch?v=PIKqWKES9ME&t=212)].
#
# ### 🛠️ Cómo crear un video paso a paso:
#
# 1. **Ingresar la idea:** Escribe tu prompt o guion en la interfaz principal. El autor utiliza como ejemplo un trailer inspirado en la película *Soy Leyenda* [[01:30](http://www.youtube.com/watch?v=PIKqWKES9ME&t=90)].
# 2. **Configuración:**
# * **Idioma:** Selecciona el idioma (incluye español) [[02:00](http://www.youtube.com/watch?v=PIKqWKES9ME&t=120)].
# * **Autoscript:** Se recomienda dejarlo activo para mejorar la producción [[02:06](http://www.youtube.com/watch?v=PIKqWKES9ME&t=126)].
# * **Duración:** Puedes elegir entre 1 y 2 minutos gratis, o más tiempo usando créditos [[02:16](http://www.youtube.com/watch?v=PIKqWKES9ME&t=136)].
# * **Formato:** Selecciona horizontal (16:9) o vertical (9:16) [[02:56](http://www.youtube.com/watch?v=PIKqWKES9ME&t=176)].
#
#
# 3. **Generación:** Al usar créditos, el proceso es inmediato y evita largas colas de espera [[03:10](http://www.youtube.com/watch?v=PIKqWKES9ME&t=190)].
# 4. **Exportación:** Los videos generados pueden descargarse **sin marca de agua** utilizando los créditos acumulados [[04:18](http://www.youtube.com/watch?v=PIKqWKES9ME&t=258)].
#
# ### ♾️ El método para obtener créditos ILIMITADOS:
#
# El autor comparte un truco de "referidos" para no tener que pagar nunca [[06:08](http://www.youtube.com/watch?v=PIKqWKES9ME&t=368)]:
#
# 1. **Enlace de referido:** Copia tu propio enlace de invitación desde la sección "Referidos" [[06:47](http://www.youtube.com/watch?v=PIKqWKES9ME&t=407)].
# 2. **Ventana de incógnito:** Abre una nueva pestaña en modo incógnito y pega tu enlace [[06:51](http://www.youtube.com/watch?v=PIKqWKES9ME&t=411)].
# 3. **Correos temporales:** Utiliza servicios de correos electrónicos desechables (que cambian cada 10 minutos) para registrar nuevas cuentas ficticias con tu enlace [[07:04](http://www.youtube.com/watch?v=PIKqWKES9ME&t=424)].
# 4. **Acumulación:** Cada registro nuevo te otorga **500 créditos**. Puedes repetir este proceso tantas veces como quieras para sumar miles de créditos rápidamente [[07:55](http://www.youtube.com/watch?v=PIKqWKES9ME&t=475)].
#
# **Enlace del video:** [http://www.youtube.com/watch?v=PIKqWKES9ME](http://www.youtube.com/watch?v=PIKqWKES9ME)

# %% [markdown]
# Este video del canal **AI en ACCIÓN** presenta una herramienta revolucionaria llamada **Chuni**, un "agente musical de IA" que permite crear canciones y convertirlas automáticamente en videoclips de alta calidad.
#
# Aquí tienes los puntos más destacados del tutorial:
#
# ### 🎶 ¿Qué es Chuni?
#
# Se describe como un productor musical y de cine con IA [[02:03](http://www.youtube.com/watch?v=stkoLlmgq0w&t=123)]. A diferencia de otras herramientas, Chuni permite una participación activa del usuario durante la generación, ofreciendo varios estilos y opciones de personalización [[04:17](http://www.youtube.com/watch?v=stkoLlmgq0w&t=257)]. Es capaz de generar música en géneros como rock, reggaetón, pop, electrónica y canciones infantiles [[01:26](http://www.youtube.com/watch?v=stkoLlmgq0w&t=86)].
#
# ### 🛠️ Cómo crear música y videoclips paso a paso:
#
# 1. **Registro y Configuración:** Regístrate con Google o correo. Un punto a favor es que la interfaz se puede cambiar completamente al **español** [[02:44](http://www.youtube.com/watch?v=stkoLlmgq0w&t=164)].
# 2. **Generación de la Canción:** * Puedes usar texto (prompts), imágenes o audios de referencia [[03:14](http://www.youtube.com/watch?v=stkoLlmgq0w&t=194)].
# * El usuario introduce un prompt detallado (incluyendo *beats* y velocidad) y la IA genera la letra y varias opciones de canciones [[03:50](http://www.youtube.com/watch?v=stkoLlmgq0w&t=230)].
#
#
# 3. **Creación del Videoclip:**
# * Una vez elegida la canción, se usa el botón de la "varita mágica" para iniciar la fase de video [[06:08](http://www.youtube.com/watch?v=stkoLlmgq0w&t=368)].
# * **Estilos:** Puedes elegir entre varios, como *Animate Wonder* (animación 3D, ideal para niños) [[06:42](http://www.youtube.com/watch?v=stkoLlmgq0w&t=402)].
# * **Personalización:** Selecciona la relación de aspecto (9:16 para TikTok/Reels o 16:9 para YouTube) y la duración del clip [[07:04](http://www.youtube.com/watch?v=stkoLlmgq0w&t=424)].
#
#
# 4. **Aprobación y Descarga:** La herramienta genera primero imágenes que luego anima. Si estás conforme con las imágenes, presionas "generar videoclip" [[08:00](http://www.youtube.com/watch?v=stkoLlmgq0w&t=480)]. El resultado final incluye animaciones fluidas y **subtítulos automáticos** [[09:17](http://www.youtube.com/watch?v=stkoLlmgq0w&t=557)].
#
# ### ♾️ Método para uso Gratuito e Ilimitado:
#
# La herramienta otorga créditos diarios que se renuevan, pero si se agotan, el autor sugiere este truco [[09:36](http://www.youtube.com/watch?v=stkoLlmgq0w&t=576)]:
#
# * Cerrar sesión en Chuni.
# * Utilizar un servicio de correos electrónicos temporales (como **10minutemail.com**) para crear una cuenta nueva [[09:57](http://www.youtube.com/watch?v=stkoLlmgq0w&t=597)].
# * Esto permite renovar los créditos tantas veces como sea necesario para seguir creando sin pagar [[10:12](http://www.youtube.com/watch?v=stkoLlmgq0w&t=612)].
#
# **Enlace del video:** [http://www.youtube.com/watch?v=stkoLlmgq0w](http://www.youtube.com/watch?v=stkoLlmgq0w)

# %% [markdown]
# Este video del canal **AI en ACCIÓN** presenta una plataforma china llamada **Roboneo**, una herramienta "todo en uno" que permite generar imágenes y videos de alta calidad de forma gratuita.
#
# Aquí tienes un resumen detallado de sus funciones y cómo usarla:
#
# ### 🌟 ¿Qué es Roboneo?
#
# Es una plataforma de IA que funciona como un chatbot (estilo ChatGPT) donde puedes solicitar la creación de contenido mediante texto. Es compatible tanto con ordenadores como con teléfonos móviles [[01:07](http://www.youtube.com/watch?v=vSCIsiErF5k&t=67)].
#
# ### 🖼️ Generación y Edición de Imágenes
#
# * **Multigeneración:** Al pedir una imagen, la IA devuelve automáticamente **cuatro variaciones** detallando los cambios realizados en cada una para ofrecer más opciones [[03:00](http://www.youtube.com/watch?v=vSCIsiErF5k&t=180)].
# * **Generación Masiva:** Permite crear hasta **20 imágenes simultáneamente** con un solo prompt (ej. 20 escenas de batalla realistas del Capitán América) manteniendo una gran calidad cinematográfica [[05:40](http://www.youtube.com/watch?v=vSCIsiErF5k&t=340)].
# * **Edición Mágica:** Incluye un pincel para seleccionar áreas específicas de una imagen y modificarlas mediante texto (ej. cambiar el color del cabello de una mujer a verde sin dejar rastros de edición) [[04:14](http://www.youtube.com/watch?v=vSCIsiErF5k&t=254)].
#
# ### 🎬 Generación de Video
#
# * **Duración:** Los videos individuales pueden durar hasta **10 segundos** [[07:27](http://www.youtube.com/watch?v=vSCIsiErF5k&t=447)].
# * **Videos Largos y Coherentes:** Si solicitas un video más largo (ej. 15 segundos), la IA genera un guion, lo divide en escenas de 5 segundos, crea las imágenes de referencia y luego las anima, manteniendo la **coherencia del personaje** a lo largo de toda la secuencia [[08:26](http://www.youtube.com/watch?v=vSCIsiErF5k&t=506)].
# * **Calidad:** Destaca por movimientos naturales, texturas realistas en la ropa y efectos de iluminación complejos [[09:47](http://www.youtube.com/watch?v=vSCIsiErF5k&t=587)].
#
# ### ♾️ Método para Uso Ilimitado (Truco de Alias)
#
# Debido a que la herramienta tiene un límite de uso diario, el autor explica el **"método de los alias"** para saltarse esta restricción [[11:40](http://www.youtube.com/watch?v=vSCIsiErF5k&t=700)]:
#
# 1. **Generar Alias:** Pide a ChatGPT que cree "100 alias" basados en tu correo electrónico real (ej. `tu.correo+1@gmail.com`, `tu.correo+2@gmail.com`).
# 2. **Nuevo Registro:** Cierra sesión y regístrate con uno de estos alias.
# 3. **Confirmación:** El código de verificación llegará a tu bandeja de entrada principal, permitiéndote crear cuentas nuevas infinitamente y resetear los límites de uso [[13:50](http://www.youtube.com/watch?v=vSCIsiErF5k&t=830)].
#
# **Enlace del video:** [http://www.youtube.com/watch?v=vSCIsiErF5k](http://www.youtube.com/watch?v=vSCIsiErF5k)

# %% [markdown]
# # Seguimos con más ......

# %% [markdown]
# Con GRok funciona bastante bien, con nano banana creamos las imagenes que luego unimos
