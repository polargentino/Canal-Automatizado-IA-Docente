# %% [markdown]
# Este video del canal **AI en ACCIÓN** explica cómo utilizar la herramienta de inteligencia artificial **Mobiflow** para convertir texto en videos cinematográficos de alta calidad de forma gratuita y sin límites.
#
# Aquí tienes los puntos clave del tutorial:
#
# ### 📽️ ¿Qué es Mobiflow?
#
# Es una plataforma de IA muy versátil que permite generar trailers, películas, videoclips, contenido educativo y dibujos animados a partir de un simple prompt o guion [[05:34](http://www.youtube.com/watch?v=PIKqWKES9ME&t=334)]. La herramienta se encarga de todo: generación de personajes, ambientes y edición completa [[03:32](http://www.youtube.com/watch?v=PIKqWKES9ME&t=212)].
#
# ### 🛠️ Cómo crear un video paso a paso:
#
# 1. **Ingresar la idea:** Escribe tu prompt o guion en la interfaz principal. El autor utiliza como ejemplo un trailer inspirado en la película *Soy Leyenda* [[01:30](http://www.youtube.com/watch?v=PIKqWKES9ME&t=90)].
# 2. **Configuración:**
# * **Idioma:** Selecciona el idioma (incluye español) [[02:00](http://www.youtube.com/watch?v=PIKqWKES9ME&t=120)].
# * **Autoscript:** Se recomienda dejarlo activo para mejorar la producción [[02:06](http://www.youtube.com/watch?v=PIKqWKES9ME&t=126)].
# * **Duración:** Puedes elegir entre 1 y 2 minutos gratis, o más tiempo usando créditos [[02:16](http://www.youtube.com/watch?v=PIKqWKES9ME&t=136)].
# * **Formato:** Selecciona horizontal (16:9) o vertical (9:16) [[02:56](http://www.youtube.com/watch?v=PIKqWKES9ME&t=176)].
#
#
# 3. **Generación:** Al usar créditos, el proceso es inmediato y evita largas colas de espera [[03:10](http://www.youtube.com/watch?v=PIKqWKES9ME&t=190)].
# 4. **Exportación:** Los videos generados pueden descargarse **sin marca de agua** utilizando los créditos acumulados [[04:18](http://www.youtube.com/watch?v=PIKqWKES9ME&t=258)].
#
# ### ♾️ El método para obtener créditos ILIMITADOS:
#
# El autor comparte un truco de "referidos" para no tener que pagar nunca [[06:08](http://www.youtube.com/watch?v=PIKqWKES9ME&t=368)]:
#
# 1. **Enlace de referido:** Copia tu propio enlace de invitación desde la sección "Referidos" [[06:47](http://www.youtube.com/watch?v=PIKqWKES9ME&t=407)].
# 2. **Ventana de incógnito:** Abre una nueva pestaña en modo incógnito y pega tu enlace [[06:51](http://www.youtube.com/watch?v=PIKqWKES9ME&t=411)].
# 3. **Correos temporales:** Utiliza servicios de correos electrónicos desechables (que cambian cada 10 minutos) para registrar nuevas cuentas ficticias con tu enlace [[07:04](http://www.youtube.com/watch?v=PIKqWKES9ME&t=424)].
# 4. **Acumulación:** Cada registro nuevo te otorga **500 créditos**. Puedes repetir este proceso tantas veces como quieras para sumar miles de créditos rápidamente [[07:55](http://www.youtube.com/watch?v=PIKqWKES9ME&t=475)].
#
# **Enlace del video:** [http://www.youtube.com/watch?v=PIKqWKES9ME](http://www.youtube.com/watch?v=PIKqWKES9ME)
