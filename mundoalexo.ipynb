# %% [markdown]
# ¡Excelente! Ahora vamos a extraer la información más relevante del tutorial de Mundoalexo DIGITAL sobre **Kdenlive** para crear una guía de aprendizaje estructurada y enfocada en la replicabilidad.
#
# Aquí tienes la información clave para dominar las funciones básicas de Kdenlive:
#
# ## 🎓 Guía de Aprendizaje Rápido: Kdenlive para Principiantes
#
# Esta guía se enfoca en las funciones esenciales para editar videos, basadas en el tutorial, con referencias temporales.
#
# ### 1. 🛠️ Configuración e Interfaz
#
# | Tema | Descripción | Referencia Temporal |
# | :--- | :--- | :--- |
# | **Instalación** | Descargar el programa desde `kdenlive.org`. Disponible para Windows, Linux y Mac. Es 100% gratuito y no requiere donación para su uso completo. | |
# | **Interfaz** | Es un sistema **multipista** (no lineal). Esto permite tener múltiples pistas de video (V1, V2, etc.) y múltiples pistas de audio (A1, A2, etc.), permitiendo superponer clips y gestionar audios separados (voz, música, efectos). | |
# | **Pistas** | `B1`, `B2`, etc., son pistas de **Video**. `A1`, `A2`, etc., son pistas de **Audio**. (Usualmente A1 o A2 para música y otra para la voz). | |
# | **Previsualización**| Tienes dos paneles: uno para previsualizar los clips importados y otro (a la derecha) para ver la línea de tiempo del proyecto que estás editando. | |
#
# ### 2. 🎬 Flujo de Trabajo Básico (Importar y Cortar)
#
# | Técnica | Procedimiento | Referencia Temporal |
# | :--- | :--- | :--- |
# | **Importar Clips** | Simplemente arrastrá el archivo (video, imagen, audio) desde tu explorador de archivos directamente al panel de "Archivos del Proyecto" en Kdenlive. | |
# | **Arrastrar a la Línea de Tiempo** | Una vez importado, arrastrá el clip desde el panel de proyectos a la pista de Video (`B1` o `B2`) deseada en la línea de tiempo. | |
# | **Cortar Clips (Método Rápido)** | Posicionate en el borde izquierdo o derecho del clip en la línea de tiempo hasta que aparezca un ícono de flechas y **arrastrá** para acortarlo al punto deseado. | |
# | **Cortar Clips (Método Tijera)** | 1. Seleccioná la **herramienta de tijera** (cuchilla) en la barra de herramientas. 2. Clicá en el punto exacto donde querés dividir el clip (aparece una línea roja). 3. Volvé a la herramienta de selección y eliminá la parte no deseada (tecla **Suprimir**). | |
# | **Unir Videos** | Simplemente colocá el segundo clip justo al lado del primero en la misma pista. | |
#
# ### 3. ✨ Efectos y Edición Esencial
#
# | Técnica | Procedimiento | Referencia Temporal |
# | :--- | :--- | :--- |
# | **Fade In / Fade Out** | **(Aparición/Desaparición gradual)** 1. Posicionate en el extremo del clip (izquierdo para **Fade In**, derecho para **Fade Out**). 2. Aparece un botón (verde a la izquierda, rojo a la derecha). 3. Hacé clic en el botón y **arrastrá** para determinar la duración del fundido. | |
# | **Eliminar Audio** | Si un clip de video tiene un audio no deseado (ej. ruido o un WhatsApp), hacé **Clic derecho** sobre el clip y seleccioná **"Desagrupar clips"**. Luego, eliminá la pista de audio (A1 o A2) que se separó. | |
# | **Zoom y Movimiento (Transformar)** | 1. Hacé **Clic derecho** en el clip > **Insertar efecto** > **Transformar**. 2. Aparecerán puntos rojos de control en el previsualizador. 3. Podés escalar (hacer zoom) y mover la posición manualmente. | |
# | **Zoom Suave (Keyframes)** | Para hacer un zoom gradual: 1. Aplicá el efecto **Transformar**. 2. Al inicio, dejá la escala al 100%. 3. Avanzá a la mitad del clip, asegurate de que el punto rojo esté seleccionado, y subí el valor de **Escala** (ej. a 150%) o arrastrá los puntos de control. Kdenlive crea la transición suave automáticamente. | |
#
# ### 4. 🎨 Elementos Visuales y Texto
#
# | Elemento | Procedimiento | Referencia Temporal |
# | :--- | :--- | :--- |
# | **Imágenes/Logos** | Arrastrá el archivo de imagen (PNG o JPG) a la pista de video **superior** (ej. `B2`). **Nota:** Si es un logo, usá formato **PNG** para que tenga fondo transparente. Hacé **Clic derecho** > **Insertar efecto** > **Transformar** para redimensionarlo y colocarlo donde desees (ej. como marca de agua). | |
# | **Crear Texto (Título)**| 1. Andá a **Proyecto** > **Crear título**. 2. Escribí el texto (ej. "Suscríbete y Dale Like"). 3. **Importante:** Si necesitás una pista de video extra para el texto, andá a la línea de tiempo, hacé **Clic derecho** > **Insertar pista** > **Pista de Video**. 4. Arrastrá el título a la pista superior. | |
# | **Ajustes de Texto** | Se ajusta el tamaño de la fuente, color, gradiente, trazo (contorno) y sombra. Para centrar el texto, usá los botones de alineación horizontal y vertical en el panel de herramientas. | |
# | **Efecto Máquina de Escribir**| En la herramienta de Título, hay un botón específico para aplicar el **"Efecto máquina de escribir"** y que el texto aparezca letra por letra. | |
#
# ### 5. 📤 Exportar el Proyecto (Renderizado)
#
# | Paso | Procedimiento | Referencia Temporal |
# | :--- | :--- | :--- |
# | **Guardar Proyecto** | **Proyecto** > **Guardar como...** (Esto guarda el archivo editable del proyecto de Kdenlive). | |
# | **Procesar/Renderizar** | 1. Hacé clic en **"Procesar"** (en la parte superior de la interfaz). 2. Asegurate de seleccionar el formato **MP4** (el formato universal y liviano recomendado). 3. Seleccioná una carpeta de destino y el nombre del archivo. 4. Hacé clic en **"Procesar archivo"**. Kdenlive es conocido por su velocidad de procesamiento. | |
#
# ---
#
# Esta guía condensa todos los pasos de edición cubiertos en el video. ¿Te gustaría que organicemos esto como un archivo `KDENLIVE_TUTORIAL.md` para el repositorio, o prefieres que busquemos más información sobre cómo combinar Kdenlive con las IA que ya hemos visto (Vidu AI, ElevenLabs)?

# %% [markdown]
# --------

# %% [markdown]
# ## en el tutorial el youtuber usa un mp4 que es un fragmento de un videojuego de un mono que salta entre niveles...dime de donde puedo extraer algo asi para replicar lo que hacer el ....
#
#
# ¡Entendido! Para replicar el tutorial de Kdenlive, necesitás un *clip de video* de tipo **"gameplay de plataformas 2D"** que sea libre de derechos de autor (o *royalty-free*).
#
# Encontrar un mono exacto saltando en un juego de plataformas puede ser muy específico, pero podés replicar el ejercicio usando cualquier clip de **"Pixel Art" o "Animación 2D"** con movimientos horizontales.
#
# Aquí te dejo tres estrategias y sitios web donde podés extraer material similar para tu proyecto docente:
#
# ## 🐒 Fuentes de Clips de Video Replicables
#
# Para obtener el fragmento de MP4 del "mono saltarín" o cualquier *gameplay* 2D, te recomiendo usar sitios con licencia **Creative Commons (CC0)**, que no requieren atribución.
#
# ### 1. 🌐 Bancos de Video Stock Gratuitos (Recomendado)
#
# Estos sitios tienen categorías de "Animación 2D" y "Pixel Art" donde podés encontrar clips cortos y listos para usar en formato MP4.
#
# * **Pexels Videos:**
#     * **Estrategia de búsqueda:** Buscá términos como `2D animation`, `pixel art game`, o `video game loop`. Estos clips suelen ser cortos y perfectos para practicar los cortes y el zoom de Kdenlive.
# * **Videezy / Videvo (Filtro CC0):**
#     * **Estrategia de búsqueda:** En estas plataformas, asegurate de aplicar el filtro de licencia **"Creative Commons 0 (CC0)"** o **"Libre de Regalías"** para que puedas usar el material sin preocuparte por la atribución.
#
# ### 2. 🕹️ Recursos de Desarrollo de Juegos (Sprites)
#
# Si no encontrás un video completo, podés usar recursos pensados para desarrolladores de videojuegos. Estos sitios ofrecen animaciones cortas ("sprites") que podés compilar o usar como imágenes en movimiento.
#
# * **Itch.io (Sección Assets):**
#     * **Estrategia de búsqueda:** Buscá `2D platformer assets free` o `sprites gratis`. Estos recursos a veces vienen con videos de ejemplo o animaciones fáciles de capturar o convertir a MP4.
# * **OpenGameArt:**
#     * **Estrategia de búsqueda:** Es una excelente fuente de gráficos y sonidos libres de derechos para juegos. Buscá `monkey sprite` o `platformer tileset` y animá una secuencia simple o descargá una animación ya hecha.
#
# ### 3. 🖼️ Clips de Animación Específicos
#
# En sitios como Shutterstock (que tiene opciones de prueba o clips gratuitos), podés encontrar clips que replican el movimiento de un personaje de juego:
#
# * **Ejemplo de búsqueda:** `cartoon monkey walking side view` o `2d game character loop`.
#
# ---
#
# **⚠️ Nota Importante para la Replicabilidad:**
#
# Si tus estudiantes no encuentran un clip de mono saltando, pueden usar **cualquier clip de video corto que tenga un objeto moviéndose** (un coche, una pelota, un logo animado) para practicar las técnicas de **corte**, **zoom (transformar)** y **movimiento de pistas** que explica el youtuber. La clave es el movimiento, no el mono.
#
# ¿Te gustaría que busquemos una alternativa al video de Kdenlive, usando Vidu AI o ElevenLabs, para continuar practicando el flujo de trabajo con la IA?
