# %% [markdown]
# # Por gemini:
#
# ## "enseñame a usar kdenlive tomando la info de este canal de yuotube: https://youtu.be/HfseZXG6oCI?si=ptWd0xVLkSF9ui5o"
# # Vídeo N°1:
# ### ¡Claro! Con gusto te explico cómo empezar a usar **Kdenlive** basándome en el tutorial del video.
#
# El video proporciona una introducción completa a los conceptos básicos, desde la configuración inicial hasta el renderizado final.
#
#
# ***
#
#
# ## 1. Configuración del Proyecto 🛠️
# Al abrir Kdenlive, se crea automáticamente un proyecto, pero puedes ajustar las configuraciones para adaptarlas a tus necesidades [01:09](http://www.youtube.com/watch?v=HfseZXG6oCI&t=69)].
#
# * **Opciones del Proyecto:** Ve al menú principal a **Proyecto** y luego a **Opciones del proyecto** [[01:17](http://www.youtube.com/watch?v=HfseZXG6oCI&t=77)].
# * **Ubicación de Archivos:** Es aconsejable cambiar la ubicación predeterminada para guardar la caché y los *proxies* a la **carpeta del proyecto** o a una **personalizada** [[01:31](http://www.youtube.com/watch?v=HfseZXG6oCI&t=91)].
# * **Formato y FPS:**
#     * En el desplegable de **FPS** (fotogramas por segundo), selecciona la tasa deseada (ej. 30 fps) [[02:01](http://www.youtube.com/watch?v=HfseZXG6oCI&t=121)].
#     * Luego, elige el **formato** que mejor se adapte a tu salida (ej. HD 1080p 30 fps) [[02:09](http://www.youtube.com/watch?v=HfseZXG6oCI&t=129)].
# * **Clips de Reemplazo (Proxies):** Para que el programa fluya mejor, especialmente con archivos grandes, ve a la pestaña **Reemplazos** y activa la opción **Clips de reemplazo**. Indica a partir de qué tamaño quieres que Kdenlive cree estos *proxies* [[02:27](http://www.youtube.com/watch?v=HfseZXG6oCI&t=147)].
#
# ***
#
# ## 2. Importación y Organización de Archivos
# La **Bandeja del Proyecto** (nombrada como multimedia) es donde se cargan los clips, imágenes y archivos que usarás [[02:49](http://www.youtube.com/watch?v=HfseZXG6oCI&t=169)].
#
# * **Importar:** Puedes arrastrar los archivos directamente desde tu navegador de archivos (como el Explorador de Windows) a la bandeja [[03:04](http://www.youtube.com/watch?v=HfseZXG6oCI&t=184)]. También puedes hacer clic derecho y seleccionar **Cargar clip o carpeta** [[03:11](http://www.youtube.com/watch?v=HfseZXG6oCI&t=191)].
# * **Organización:** Kdenlive permite crear **carpetas** dentro de la bandeja para distribuir y organizar mejor tus archivos, facilitando su búsqueda [[03:26](http://www.youtube.com/watch?v=HfseZXG6oCI&t=206)].
#
# ***
#
# ## 3. Trabajo en la Línea de Tiempo (Timeline) 🎬
# El *timeline* es donde se realiza todo el trabajo de edición [[03:34](http://www.youtube.com/watch?v=HfseZXG6oCI&t=214)].
#
# ### Pistas y Clips
# * **Crear Pistas:** Haz clic derecho sobre las cabeceras de las pistas para crear nuevas pistas (vídeo o audio) [[03:47](http://www.youtube.com/watch?v=HfseZXG6oCI&t=227)].
# * **Añadir Clips:** Simplemente arrastra tu clip desde la bandeja de proyecto a la línea de tiempo [[04:15](http://www.youtube.com/watch?v=HfseZXG6oCI&t=255)]. Un clip con audio ocupará una pista de vídeo y una de audio vinculadas [[04:22](http://www.youtube.com/watch?v=HfseZXG6oCI&t=262)].
# * **Desagrupar Clips:** Si quieres eliminar solo la pista de audio o vídeo, primero debes desvincularlas. Haz clic derecho sobre la pista y busca la opción **Desagrupar clips**. Luego puedes seleccionar y eliminar solo la parte que desees (ej. la de audio) usando la tecla **Suprimir** [[04:28](http://www.youtube.com/watch?v=HfseZXG6oCI&t=268)].
#
# ### Corte y Movimiento
# * **Cortar:** Usa la herramienta de **tijeras** que se encuentra sobre el *timeline* o su atajo de teclado, la letra **X**, para cortar el clip donde desees [[04:57](http://www.youtube.com/watch?v=HfseZXG6oCI&t=297)].
# * **Seleccionar/Mover:** Para mover o volver al modo de selección, selecciona la **flecha de selección** o pulsa la tecla **S**. Con el cursor, podrás mover los clips a la posición deseada [[05:12](http://www.youtube.com/watch?v=HfseZXG6oCI&t=312)].
#
# ### Fundidos y Transiciones
# Al posicionarte sobre un clip en el *timeline*, aparecen puntos en las esquinas [[05:29](http://www.youtube.com/watch?v=HfseZXG6oCI&t=329)]:
#
# * **Fundido a Negro (Opacidad):** Los puntos **superiores** te permiten arrastrar para crear un **fundido a negro** al inicio o al final del clip [[05:37](http://www.youtube.com/watch?v=HfseZXG6oCI&t=337)].
# * **Transiciones Simples:** Los puntos **inferiores** crean una **transición sencilla** (por defecto, también un fundido a negro) entre clips [[05:43](http://www.youtube.com/watch?v=HfseZXG6oCI&t=343)].
#
# ### Zoom
# Para hacer *zoom* en el *timeline* puedes usar **Control + Rueda del *Mouse*** [[06:04](http://www.youtube.com/watch?v=HfseZXG6oCI&t=364)], o manipular la barra de la parte inferior: arrastrar el punto derecho hacia la izquierda acerca la vista (zoom), y ensanchar la barra la aleja [[06:09](http://www.youtube.com/watch?v=HfseZXG6oCI&t=369)].
#
# ***
#
# ## 4. Efectos y Títulos
# ### Efectos
# * Todos los ajustes sobre un clip de vídeo o audio en Kdenlive se manejan como **efectos** [[06:44](http://www.youtube.com/watch?v=HfseZXG6oCI&t=404)].
# * Los efectos se encuentran organizados por categorías en la **pestaña de efectos** [[06:50](http://www.youtube.com/watch?v=HfseZXG6oCI&t=410)].
#
# ### Títulos y Animación
# * **Crear un Título:** Kdenlive tiene un **editor de texto** independiente para crear un clip de título simple (fuente, tamaño, color, etc.) [[07:23](http://www.youtube.com/watch?v=HfseZXG6oCI&t=443)].
# * **Animación (Keyframes):** Para animar un título, se usan los **fotogramas clave** (*keyframes*), que son etiquetas que guardan los datos de una propiedad en un punto específico. Kdenlive calcula los valores intermedios (*interpolación*) para crear una transición suave [[07:38](http://www.youtube.com/watch?v=HfseZXG6oCI&t=458)].
# * **Efecto Transformación:** Los clips de texto necesitan el efecto **Transformación** para poder animar propiedades básicas como la **posición**, el **tamaño** o la **opacidad** mediante *keyframes* [[08:09](http://www.youtube.com/watch?v=HfseZXG6oCI&t=489)].
#
# ***
#
# ## 5. Renderizado Final 💾
# El renderizado es el proceso para obtener el archivo final de tu proyecto [[08:39](http://www.youtube.com/watch?v=HfseZXG6oCI&t=519)].
#
# * **Formatos Recomendados:** El video aconseja no tocar muchos parámetros para evitar problemas de compatibilidad.
#     * Para la mayoría de los casos, recomienda renderizar en **MP4** [[08:53](http://www.youtube.com/watch?v=HfseZXG6oCI&t=533)].
#     * Si necesitas **transparencias**, recomienda usar **Mov** o, para videos muy cortos, **Gif** [[09:01](http://www.youtube.com/watch?v=HfseZXG6oCI&t=541)].
#
# Puedes encontrar más tutoriales de Kdenlive en el canal [JGuidus-Media tutoriales](http://www.youtube.com/watch?v=HfseZXG6oCI) [[09:48](http://www.youtube.com/watch?v=HfseZXG6oCI&t=588)].
#
#
# http://googleusercontent.com/youtube_content/0

# %% [markdown]
# # Vídeo N°2:
#
# ¡Claro! Este video es muy útil para la creación de contenido, ya que muestra cómo usar la nueva herramienta de subtitulado automático con Inteligencia Artificial de Kdenlive.
#
# Aquí tienes la guía de estudio detallada del video **"🎬 Cómo Crear SUBTITULOS en tus Videos GRATIS y Automáticamente en Kdenlive"**:
#
# ***
#
# ## Guía Detallada: Cómo Crear Subtítulos Automáticos en Kdenlive
#
# **Video:** [http://www.youtube.com/watch?v=h8AYxVdh7OQ](http://www.youtube.com/watch?v=h8AYxVdh7OQ)
# **Objetivo:** Aprender a instalar y usar la herramienta de reconocimiento de voz integrada de Kdenlive (basada en el modelo Whisper) para generar subtítulos de manera automática, gratuita y rápida.
#
# ### 1. Instalación del Modelo de Reconocimiento de Voz
#
# Antes de generar subtítulos, es necesario descargar los modelos de IA que realizan la transcripción.
#
# * **Acceder a la herramienta:**
#     1.  Ve a la opción **Proyecto** en el menú superior [[01:11](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=71)].
#     2.  Selecciona **Subtítulos** (`Subtitles`).
#     3.  Elige **Reconocimiento de voz** (`Speech Recognition`) [[01:17](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=77)].
# * **Configurar e Instalar Modelos:**
#     1.  Al aparecer la advertencia inicial, pulsa el botón **Configuración** [[01:34](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=94)].
#     2.  Asegúrate de que el modo seleccionado sea **Whisper**, ya que se recomienda por su precisión [[01:58](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=118)].
#     3.  Haz clic en **Administrar modelos** (`Manage Models`) [[02:06](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=126)].
#     4.  **Selecciona un modelo en español** (evitando los que tienen extensión `n` de *english*) [[02:22](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=142)].
#     5.  **Recomendación del Modelo:** Se aconseja elegir el modelo **Medium** [[02:32](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=152)]. Es más preciso que los modelos `tiny` o `sm` y ocupa menos espacio que el modelo `large` [[02:40](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=160)].
#     6.  Una vez seleccionado, haz clic en **Instalar** y espera a que el proceso de descarga e instalación finalice [[02:47](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=167)].
# * **Verificación Final:**
#     1.  Vuelve al panel de configuración.
#     2.  Selecciona el idioma **Español** para facilitar el trabajo a la IA (aunque podría detectarlo automáticamente) [[03:13](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=193)].
#     3.  Haz clic en **Comprobar configuración** [[03:37](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=217)]. Si la configuración es correcta, aparecerá un mensaje en verde [[03:45](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=225)].
#
# ### 2. Generación Automática de Subtítulos
#
# Con el modelo instalado, ya puedes procesar la transcripción de tu secuencia:
#
# * **Iniciar el Reconocimiento de Voz:**
#     1.  Vuelve a **Proyecto** -> **Subtítulos** -> **Reconocimiento de voz** [[03:54](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=234)].
#     2.  El modelo instalado debe aparecer en el desplegable superior [[04:03](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=243)].
#     3.  Ajusta la **Cantidad máxima de caracteres por línea**. El presentador recomienda bajarlo a **12** para asegurar que los subtítulos sean cortos y dinámicos [[04:10](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=250)].
#     4.  **Selección de Secuencia:** Asegúrate de cambiar la opción de procesamiento a **"trabajar sobre toda la secuencia"** (en lugar de solo un clip seleccionado) [[04:24](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=264)].
#     5.  Haz clic en **Procesar** [[04:30](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=270)].
# * **Resultado:** El programa procesará el audio (tardará según la duración del diálogo) y los subtítulos aparecerán automáticamente en una **pista de subtítulos** dedicada, listos para editar [[04:45](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=285)].
#
# ### 3. Edición y Personalización de Subtítulos
#
# Kdenlive permite modificar el texto y el estilo de los subtítulos generados:
#
# * **Edición de Texto:** La herramienta proporciona todas las opciones necesarias para corregir cualquier error de transcripción [[04:52](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=292)].
# * **Cambio de Apariencia/Estilo:** Puedes crear un nuevo estilo de subtítulo para cambiar la fuente, color, tamaño, etc. Cualquier modificación en el estilo por defecto (**default**) se aplicará a todos los fragmentos de subtítulos a la vez [[05:04](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=304)].
# * **Limitación de Animación:** Es importante notar que los clips de subtítulos generados **no admiten efectos de animación** directamente [[05:14](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=314)]. Si deseas animar el texto (por ejemplo, con efectos de movimiento o zoom), debes copiar el texto a una **pista de video normal** como un clip de texto y aplicar los efectos allí [[05:21](http://www.youtube.com/watch?v=h8AYxVdh7OQ&t=321)].
#
#
#
# http://googleusercontent.com/youtube_content/15

# %% [markdown]
# Gracias por proporcionar la documentación. La información que proporcionaste sobre la configuración de Kdenlive y el uso de VOSK es excelente y nos permite identificar los posibles puntos de fallo y cómo resolverlos.
#
# Dado que el modelo pequeño falló, ahora debes usar el modelo grande que instalaste: **`vosk-model-es-0.42`**.
#
# Aquí está la guía paso a paso, usando la documentación y tu configuración actual, para transcribir correctamente tu archivo MP3.
#
# ## ✍️ Guía de Transcripción con VOSK (Modelo Grande)
#
# ### 1. Preparación del Proyecto
#
# 1.  **Reinicia Kdenlive (AppImage):** Esto asegura que Kdenlive reconozca el nuevo modelo grande que copiaste (`vosk-model-es-0.42`).
# 2.  **Abre tu Proyecto.**
# 3.  **Verifica el Audio:** Arrastra el clip `.mp3` a la línea de tiempo. **Reproduce el clip** y confírmanos que **suena a velocidad normal**. Si suena acelerado (como tu clip anterior de 2 segundos), la transcripción no funcionará correctamente, ya que VOSK lo interpretará como un ruido muy corto.
#     * Si está acelerado: Haz clic derecho en el clip, selecciona **Cambiar velocidad...** y redúcela (ej., a 25%) hasta que suene normal.
#
# ### 2. Configuración y Subtitulado Automático
#
# El proceso que debes seguir es el de **Creación de subtítulos usando reconocimiento de voz de VOSK**.
#
# 1.  **Pista de Subtítulos:** Asegúrate de que tienes una pista de subtítulos creada. Puedes agregarla haciendo clic en el botón **Editar subtítulos** en la Barra de herramientas de la Línea de tiempo.
# 2.  **Abrir la Ventana de Transcripción:** Haz clic derecho en el clip de audio en la línea de tiempo y selecciona **Voz a texto**. Esto abrirá la ventana **Subtitulado automático**.
# 3.  **Seleccionar el Modelo:** En la ventana **Subtitulado automático**:
#     * En el menú desplegable **Modelo**, selecciona tu modelo más preciso: **`vosk-model-es-0.42`**.
# 4.  **Seleccionar el Clip:** Debajo de las opciones de zona, escoge **Clip seleccionado**.
#
# ### 3. Procesar y Visualizar el Resultado
#
# 1.  **Iniciar Procesamiento:** Haz clic en el botón **Procesar**.
# 2.  **Esperar:** El procesamiento tomará un tiempo (depende de la duración del audio y la velocidad de tu CPU).
# 3.  **Verificar Subtítulos:** Una vez finalizado, los subtítulos **serán creados e insertados de manera automática** en la pista de subtítulos que creaste.
#
# **Los subtítulos no aparecen como texto en la terminal o en una ventana emergente; aparecen como objetos de subtítulos en la Pista de Subtítulos de tu línea de tiempo.** Deberías ver pequeñas cajas de texto en esa pista.
#
# ---
#
# **Pregunta clave:** ¿Estás seguro de que tu clip de audio `.mp3` **no está acelerado** y de que seleccionaste el **modelo grande** (`vosk-model-es-0.42`) antes de hacer clic en **Procesar**?
#
# Si después de seguir estos pasos con el modelo grande y el clip a velocidad normal no aparecen subtítulos en la línea de tiempo, el problema es que el clip tiene una calidad de audio demasiado baja (por ejemplo, mucho ruido o música de fondo) para que VOSK lo reconozca.

# %% [markdown]
# # Vídeo N°3:

# %% [markdown]
# ¡Absolutamente! Este video es excelente para darle un toque dinámico y profesional a tus videos al crear **tercios inferiores** (o *lower thirds*) animados.
#
# Aquí tienes la guía de estudio detallada para el video **"🌟Increíbles Tercios Inferiores Animados En Kdenlive: Paso A Paso"**:
#
# ***
#
# ## Guía Detallada: Tercios Inferiores Animados en Kdenlive
#
# **Video:** [http://www.youtube.com/watch?v=mvDSs7eMF9A](http://www.youtube.com/watch?v=mvDSs7eMF9A)
# **Objetivo:** Aprender dos métodos para crear y animar tercios inferiores (cartelas) profesionales utilizando el editor de títulos, clips de color y el efecto **Transformación** con *keyframes* y distintas interpolaciones.
#
# ***
#
# ## 1. Método 1: Creación de Elementos Separados (Fondo y Texto)
#
# Este método anima el fondo y el texto de manera independiente, permitiendo que el texto aparezca *después* de que el fondo se haya desplegado.
#
# ### A. Creación y Animación del Fondo (Clip de Color)
#
# 1.  **Crear Clip de Color:** Clic derecho sobre la ventana de Medios (**Medios de proyecto**) y selecciona **Crear clip de color** [[00:54](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=54)]. Elige el color deseado.
# 2.  **Preparación:** Arrastra el clip a la línea de tiempo (V2) y acorta su duración [[01:07](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=67)].
# 3.  **Aplicar Efecto:** Aplica el efecto **Transformación** (`Transformation`) al clip de color [[01:21](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=81)].
# 4.  **Ajustar Forma:**
#     * Aparecerán tiradores para ajustar el tamaño.
#     * En los ajustes del efecto, marca la casilla **Distorsionar** (`Distort`) para poder modificar la altura y anchura de forma independiente [[01:46](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=106)].
#     * Ajusta el rectángulo a la forma deseada para el tercio inferior.
# 5.  **Animación de Despliegue/Repliegue:**
#     * **Keyframe 1 (Inicial):** Posiciónate al inicio. Reduce la **Anchura** a `1` (cero no funciona en Kdenlive) para que esté escondido [[02:40](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=160)].
#     * **Keyframe 2 (Despliegue):** Avanza un poco y crea un *keyframe*. Restaura la anchura a su tamaño final (rectángulo desplegado) [[02:02](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=122)].
#     * **Keyframe 3 (Pausa):** Avanza hasta donde quieres que termine la pausa y crea otro *keyframe* [[02:10](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=130)].
#     * **Keyframe 4 (Repliegue/Salida):** Al final del clip, crea el último *keyframe* y vuelve a reducir la **Anchura** a `1` [[02:22](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=142)].
#     * **Mejora de Interpolación:** Para un movimiento más suave, selecciona todos los *keyframes* y cambia la **Interpolación** a **Suave** (`Smooth`) [[02:58](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=178)].
#
# ### B. Creación y Sincronización del Texto
#
# 1.  **Crear Clip de Título:** Clic derecho en **Medios de proyecto** y selecciona **Crear título** [[03:13](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=193)].
# 2.  **Ajustar Texto:** Escribe, selecciona la fuente y el tamaño, y posiciona el texto en el centro del rectángulo [[03:25](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=205)].
# 3.  **Efecto de Escritura:** Activa la función **Máquina de Escribir** (`Typewriter`) para que el texto aparezca letra por letra [[03:31](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=211)].
# 4.  **Colocación en Pista:**
#     * Inserta una **nueva pista de video** (V3) por encima de las anteriores [[03:41](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=221)].
#     * Arrastra el clip de texto a V3.
#     * **Sincronización:** Mueve el clip de texto para que su inicio coincida **justo después** de que el rectángulo de color haya terminado su animación de despliegue [[03:56](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=236)].
# 5.  **Animación de Salida (Opcional):** Aplica el efecto **Transformación** al clip de texto para animar la **Opacidad** (`Opacity`). Baja la opacidad a `0` justo antes de que el fondo comience su animación de repliegue [[04:17](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=257)].
#
# ***
#
# ## 2. Método 2: Creación de Elemento Único (Título con Gráficos)
#
# Este método es más eficiente al agrupar todos los elementos (rectángulo, logo y texto) en un solo clip de título, simplificando la animación.
#
# ### A. Creación del Clip de Título Compuesto
#
# 1.  **Abrir Editor de Títulos:** Ve a **Proyecto** -> **Añadir clip de título** [[04:44](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=284)].
# 2.  **Añadir Gráficos:**
#     * Utiliza la herramienta de **Rectángulo** para crear el fondo de la cartela [[04:47](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=287)].
#     * **Importar Imagen:** Utiliza la opción **Importar** para añadir un logo (debe ser un archivo **PNG** con fondo transparente) [[05:04](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=304)]. Ajusta su tamaño y posición.
# 3.  **Añadir Texto:** Escribe el nombre o información. Ajusta fuente, color y añade una **Sombra** para mejor contraste [[05:18](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=318)].
# 4.  **Finalizar:** Haz clic en **Crear título** [[05:32](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=332)]. Ahora tienes un solo clip que contiene todo.
#
# ### B. Animación con Interpolación de Rebote
#
# Este método usa la interpolación de *rebote* para un efecto de entrada y salida más profesional:
#
# 1.  **Aplicar Efecto:** Arrastra el nuevo clip de título a la línea de tiempo y aplica el efecto **Transformación** [[05:46](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=346)].
# 2.  **Keyframe 1 (Entrada):**
#     * Posiciona el cabezal donde quieres que la cartela quede fija. Crea un *keyframe* [[05:54](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=354)].
#     * Cambia su interpolación a **Rebote Entrante** (`Bounce In`) [[05:58](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=358)].
# 3.  **Keyframe 2 (Pausa):** Avanza casi al final y crea otro *keyframe*.
# 4.  **Keyframe 3 (Salida):**
#     * Al final del clip, crea el último *keyframe* [[06:14](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=374)].
#     * Mueve la cartela completamente **fuera de la pantalla a la izquierda** ajustando el valor **X** del efecto [[06:17](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=377)].
# 5.  **Keyframe 4 (Posición Inicial):**
#     * Vuelve al inicio del clip (el primer *keyframe* en la línea de tiempo de Transformación).
#     * Mueve la cartela completamente **fuera de la pantalla a la izquierda** (usando el mismo valor X del Keyframe 3) [[06:29](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=389)].
#     * Ajusta la interpolación de los *keyframes* de inicio y fin (ej. **Rebote Saliente** y **Suave**) hasta conseguir el efecto deseado de entrada con rebote, pausa, y salida con rebote [[07:05](http://www.youtube.com/watch?v=mvDSs7eMF9A&t=425)].
#
#
#
# http://googleusercontent.com/youtube_content/17

# %% [markdown]
# # Vídeo N°4:

# %% [markdown]
# ¡Excelente! El video número 8 de la serie es un tutorial muy creativo sobre un efecto de texto dinámico y llamativo.
#
# Aquí tienes la guía de estudio detallada para el video **"🎥 Tutorial de texto cinematográfico de Kdenlive | Paso a paso"**:
#
# ***
#
# ## Guía Detallada: Efecto de Texto Cinematográfico en Kdenlive
#
# **Video:** [http://www.youtube.com/watch?v=Wn182fekP8Y](http://www.youtube.com/watch?v=Wn182fekP8Y)
# **Objetivo:** Crear un efecto de texto donde las letras actúan como máscaras, revelando un video de fondo, y luego animar ese texto para que se separe o deslice fuera de la pantalla.
#
# ### 1. Preparación de Clips
#
# Necesitas tres elementos básicos para este efecto:
#
# 1.  **Fondo de Vídeo:** El clip que quieres que se vea *dentro* del texto. Arrástralo a la pista **V1** [[00:34](http://www.youtube.com/watch?v=Wn182fekP8Y&t=34)].
# 2.  **Clip de Color:** Un clip de color **Blanco** que servirá como base para la animación. Arrástralo a la pista **V2** [[00:41](http://www.youtube.com/watch?v=Wn182fekP8Y&t=41)].
# 3.  **Clip de Texto (Máscara):**
#     * Crea un nuevo clip de texto [[00:49](http://www.youtube.com/watch?v=Wn182fekP8Y&t=49)].
#     * Usa una **fuente gruesa** y **negrita** y aumenta el tamaño para que ocupe gran parte de la pantalla.
#     * **Asegúrate de centrar el texto** horizontal y verticalmente [[00:56](http://www.youtube.com/watch?v=Wn182fekP8Y&t=56)].
#     * Cambia el color del texto a **Verde** (este color será clave para el *chroma key*) [[01:05](http://www.youtube.com/watch?v=Wn182fekP8Y&t=65)].
#     * Aplica el efecto **Máquina de Escribir** (`Typewriter`) al texto: haz doble clic en el clip para abrir el editor, marca la casilla, y ajusta el **intervalo de fotogramas** a `3` (por defecto es 1) para hacerlo más lento [[01:21](http://www.youtube.com/watch?v=Wn182fekP8Y&t=81)].
#
# ### 2. Creación de la Secuencia Compuesta (Clip Único)
#
# El video de fondo y la máscara de texto deben combinarse en un solo clip para poder aplicar la máscara final.
#
# * **Crear Secuencia:**
#     1.  Selecciona el **Clip de Color (V2)** y el **Clip de Texto (V3)** manteniendo presionada la tecla **Shift** [[01:50](http://www.youtube.com/watch?v=Wn182fekP8Y&t=110)].
#     2.  Clic derecho sobre la selección -> **Crear secuencia a partir de selección** [[02:04](http://www.youtube.com/watch?v=Wn182fekP8Y&t=124)].
#     3.  Nombra la nueva composición (Secuencia) [[02:12](http://www.youtube.com/watch?v=Wn182fekP8Y&t=132)]. Este clip compuesto contendrá la animación del texto verde sobre el fondo blanco.
# * **Ajuste Inicial:** Inserta el clip de color blanco al inicio de la secuencia para rellenar el espacio antes de que comience la animación de la máquina de escribir [[02:15](http://www.youtube.com/watch?v=Wn182fekP8Y&t=135)].
#
# ### 3. Aplicación del Chroma Key y la Máscara de Revelado
#
# Esta es la parte central del efecto, donde el texto verde se vuelve transparente para revelar el fondo.
#
# 1.  **Chroma Key para Transparencia:**
#     * Aplica el efecto **Pantalla azul (recorte por color)** (que se encuentra en **Alfa, enmascaramiento y recorte**) al **clip compuesto (Secuencia)** [[02:35](http://www.youtube.com/watch?v=Wn182fekP8Y&t=155)].
#     * Selecciona el color del texto (verde) usando el **gotero** en los ajustes del efecto [[02:51](http://www.youtube.com/watch?v=Wn182fekP8Y&t=171)].
#     * **Resultado:** El color verde del texto se elimina, dejando un agujero en forma de letra que revela el vídeo de la pista **V1** que está debajo [[03:00](http://www.youtube.com/watch?v=Wn182fekP8Y&t=180)].
#
# 2.  **División y Máscara (Efecto de Apertura):**
#     * Corta el clip compuesto en dos:
#         * La **primera parte** debe terminar justo donde finaliza la animación de **Máquina de Escribir** [[03:22](http://www.youtube.com/watch?v=Wn182fekP8Y&t=202)].
#         * La **segunda parte** es el texto completo estático.
#     * Aplica el efecto **Máscara alfa rectangular** (`Rectangular Alpha Mask`) a ambas partes del clip compuesto (V2) [[03:39](http://www.youtube.com/watch?v=Wn182fekP8Y&t=219)].
#
# ### 4. Animación de Salida (Separación del Texto)
#
# Se utiliza el efecto **Transformación** y la máscara para hacer que el texto se separe del centro de la pantalla.
#
# 1.  **Configurar Máscara para Centro (V2):**
#     * En la primera mitad del clip compuesto (donde está la animación de Máquina de Escribir), en los ajustes de **Máscara alfa rectangular**, crea un *keyframe* inicial.
#     * Ajusta el valor de **Abajo** (`Bottom`) a **500** [[04:02](http://www.youtube.com/watch?v=Wn182fekP8Y&t=242)]. (Kdenlive usa un valor de 1000 como máximo para el formato, por lo que 500 es el centro).
# 2.  **Configurar Máscara para Centro (V3):**
#     * En la segunda mitad del clip compuesto (donde el texto es estático), aplica los ajustes de máscara.
#     * Crea un *keyframe* inicial.
#     * Ajusta el valor de **Arriba** (`Top`) a **500** [[04:25](http://www.youtube.com/watch?v=Wn182fekP8Y&t=265)].
#     * **Resultado:** La segunda parte del clip está ahora partida por la mitad (una mitad visible, la otra invisible) [[04:36](http://www.youtube.com/watch?v=Wn182fekP8Y&t=276)].
#
# 3.  **Animación de Transformación (Separación):**
#     * Aplica el efecto **Transformación** a **ambas mitades** del clip [[04:46](http://www.youtube.com/watch?v=Wn182fekP8Y&t=286)].
#     * **Clip 1 (Mitad Superior):**
#         * Crea un *keyframe* inicial.
#         * Avanza unos 2 segundos [[04:59](http://www.youtube.com/watch?v=Wn182fekP8Y&t=299)] y crea un segundo *keyframe*.
#         * Modifica el valor de la **Posición Y** para que la parte superior del texto se deslice fuera de la pantalla **hacia arriba** [[05:15](http://www.youtube.com/watch?v=Wn182fekP8Y&t=315)].
#     * **Clip 2 (Mitad Inferior):**
#         * Sin mover el cabezal de reproducción, crea un *keyframe* inicial y un segundo *keyframe* en el mismo punto que el Clip 1 [[05:25](http://www.youtube.com/watch?v=Wn182fekP8Y&t=325)].
#         * Modifica el valor de la **Posición Y** para que la parte inferior del texto se deslice fuera de la pantalla **hacia abajo** [[05:31](http://www.youtube.com/watch?v=Wn182fekP8Y&t=331)].
#
# **Resultado Final:** El video se revela a través de las letras (Máquina de Escribir), y una vez completo, el texto se divide por la mitad y se desliza fuera de la pantalla [[05:40](http://www.youtube.com/watch?v=Wn182fekP8Y&t=340)].
#
#
#
# http://googleusercontent.com/youtube_content/19

# %% [markdown]
# # Seguimos con Jguidus

# %% [markdown]
# ¡Excelente! Este video es la continuación del tutorial de subtítulos y revela un truco avanzado para hacer que tus subtítulos sean dinámicos y atractivos, al estilo *karaoke*.
#
# Aquí tienes la guía de estudio detallada para el video **"Kdenlive: El truco de subtítulos dinámicos que NECESITAS saber"**:
#
# ***
#
# ## Guía Detallada: El Truco de Subtítulos Dinámicos en Kdenlive
#
# **Video:** [http://www.youtube.com/watch?v=PJYyV5xm_8U](http://www.youtube.com/watch?v=PJYyV5xm_8U)
# **Objetivo:** Aprender a utilizar los códigos de formato ASS (Advanced SubStation Alpha) dentro de los clips de subtítulos de Kdenlive para crear efectos dinámicos como el resaltado de palabras al ritmo de la voz (efecto karaoke).
#
# ### 1. Creación y Edición de Estilos de Subtítulos
#
# Aunque los subtítulos en Kdenlive no admiten animación de video directa, sí permiten personalización de estilos que se pueden aprovechar con los códigos de formato.
#
# * **Paso Inicial:** Genera los subtítulos automáticamente a partir de un clip de audio (como se explicó en el video anterior) [[00:51](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=51)].
# * **Acceder a Estilos:** Haz doble clic en el clip de subtítulo para ver sus propiedades [[01:15](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=75)].
# * **Crear Nuevo Estilo:** En la ventana de propiedades, abre el **Administrador de estilos** (`Style Manager`) [[01:31](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=91)] y selecciona **Crear nuevo estilo** (`Create new style`) [[01:45](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=105)].
# * **Configuración del Estilo:** Al crear un estilo nuevo (ej. "Bangers" de tamaño 100), se pueden definir:
#     * **Tipografía, tamaño y negrita** [[01:48](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=108)].
#     * **Color principal** [[01:57](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=117)].
#     * **Color secundario:** Este color es crucial, ya que es el que se usará para **resaltar** las palabras dinámicamente con el efecto *karaoke* [[01:57](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=117)].
#     * **Contorno** [[02:02](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=122)].
# * **Aplicar Estilo:** Selecciona el estilo recién creado en las propiedades del clip para aplicarlo [[02:14](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=134)]. (Nota: Tienes que ir clip por clip).
#
# ### 2. Uso de Códigos de Formato ASS
#
# La clave para la dinámica es la inserción manual de códigos del formato ASS (SubStation Alpha) dentro del texto del subtítulo.
#
# * **Visualización de Códigos de Estilo:** Si modificas el estilo (ej. fuente) directamente en un clip, Kdenlive inserta códigos de estilo automáticamente (ej. `{\\fnBanger\\fs100...}`) que definen la tipografía, tamaño y demás [[02:26](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=146)]. Esto demuestra que los códigos ASS funcionan.
# * **Acceder a la Lista de Códigos:** Al escribir una barra invertida `\` dentro de corchetes `{}` en el texto del subtítulo, se despliega la lista de códigos ASS disponibles [[03:14](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=194)].
#
# #### Implementación del Efecto Karaoke:
#
# 1.  **Código Base:** Usa el código `{\\kf<tiempo>}`:
#     * `\k`: Comando de **karaoke**.
#     * `f`: Añade un efecto de **barrido** al resaltado.
#     * `<tiempo>`: Define la duración del efecto en **centisegundos** [[03:22](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=202)].
#
# 2.  **Inserción y Ajuste:**
#     * Inserta el código, por ejemplo `{\\kf50}` (50 centisegundos = 0.5 segundos), inmediatamente **antes** de la palabra que deseas resaltar [[03:22](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=202)].
#     * **El código resalta todas las palabras que están entre el código y el final del clip, usando el color secundario** [[03:41](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=221)].
#     * Para hacer que solo una palabra se resalte, debes **repetir el código** justo después de esa palabra.
#     * **Sincronización:** Debes **ajustar el valor del tiempo** (`<tiempo>`) para que el barrido coincida exactamente con la duración de la palabra hablada en el audio [[03:59](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=239)].
#
# ### 3. Exportación de Subtítulos
#
# Una vez que los subtítulos dinámicos están listos, debes exportar el archivo ASS para usarlo en otras plataformas (como YouTube, que acepta subtítulos con efectos dinámicos).
#
# * **Exportar Archivo ASS:**
#     1.  Haz clic en el pequeño desplegable en la cabecera de la pista de subtítulos [[04:22](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=262)].
#     2.  Selecciona **Administrar subtítulos** (`Manage Subtitles`). Esto mostrará la ruta del archivo ASS creado.
#     3.  Usa el botón de **menú** (esquina inferior derecha) y selecciona **Exportar** para guardar el archivo `.ass` en la ubicación deseada [[04:37](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=277)].
#
# > **Nota:** El presentador promete un futuro video para mostrar cómo hacer que los subtítulos sean animados (no solo resaltados) pasándolos a una pista de texto normal [[04:45](http://www.youtube.com/watch?v=PJYyV5xm_8U&t=285)].
#
#
# http://googleusercontent.com/youtube_content/21

# %% [markdown]
# Entiendo. Parece que estás siguiendo el tutorial de **subtítulos dinámicos** (efecto *karaoke*). El problema que ves es que, aunque tienes códigos de formato, el texto no está haciendo el **barrido de color** como le sale al profesor.
#
# La razón es que tu clip de subtítulos solo contiene códigos de **estilo estático**, pero **le falta el código de animación dinámica**.
#
# ---
#
# ## 🧐 Análisis del Código de Formato
#
# Tu clip de subtítulos muestra lo siguiente: `{\\fnSpecial Elite\\fs120\\b0\\a0\\i0\\u0\\s0}guía`
#
# * Estos son códigos de estilo ASS (Advanced SubStation Alpha) que definen la **fuente** (`\fn`), el **tamaño** (`\fs`), y que la negrita, cursiva, subrayado y sombra están apagados (`0`).
# * **Estos códigos no son el efecto *karaoke***.
#
# ---
#
# ## ✅ La Solución: Insertar el Código Dinámico
#
# Para lograr el efecto de barrido y resaltado que usa el profesor, debes insertar el código `{\\kf<tiempo>}`.
#
# ### 1. El Código Requerido
#
# El profesor usó el código de **karaoke** (`\kf`) que aplica un **barrido** usando el **Color Secundario** que definiste en el estilo:
#
# * **Inserta:** `{\\kf<tiempo>}`
#
# Donde `<tiempo>` es la duración del efecto en **centisegundos** (ej. 50 centisegundos = 0.5 segundos).
#
# ### 2. Dónde Insertarlo
#
# Debes insertar el código **justo antes de la palabra o letra** que quieres que empiece a destacarse:
#
# | Título del Clip (Actual) | Título del Clip (Necesario para el efecto) |
# | :--- | :--- |
# | `{\\fn...}guía` | `{\\fn...}{\\kf50}guía` |
#
# ### 3. Verificar el Color Secundario
#
# Recuerda que el efecto de karaoke usa el **Color Secundario** que definiste en el **Administrador de estilos**.
#
# 1.  Asegúrate de que el estilo que estás usando (o el que creaste) tenga un **Color Secundario** llamativo (ej. amarillo o rojo).
# 2.  Si el texto no se resalta, verifica que el código `{\\kf<tiempo>}` esté insertado correctamente en el clip.

# %% [markdown]
# ¡Absolutamente! Este video es fundamental para avanzar en la edición, ya que explica una de las herramientas más potentes: las **máscaras**.
#
# Aquí tienes la guía de estudio detallada para el tutorial **"¡DOMINA el arte de las MÁSCARAS en Kdenlive! 🎭 El tutorial RÁPIDO y FÁCIL en 6 MINUTOS ⏱️"**:
#
# ***
#
# ## Guía Detallada: Dominando el Arte de las Máscaras en Kdenlive
#
# **Video:** [http://www.youtube.com/watch?v=qRqu_iJHtU0](http://www.youtube.com/watch?v=qRqu_iJHtU0)
# **Objetivo:** Aprender a usar las diferentes herramientas de máscara de Kdenlive, entendiendo que una máscara (*mate*) es un gráfico en blanco y negro donde el blanco representa **opacidad** y el negro representa **transparencia** (`alfa`) [[01:46](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=106)].
#
# ***
#
# ### 1. El Concepto Básico (Luma Key)
#
# El método tradicional para usar un gráfico como máscara es a través del *Luma Key* (que Kdenlive gestiona de diversas formas):
#
# * **Principio:** Si colocas un gráfico de texto en blanco y negro en una pista superior, el efecto **Luma Key** (o similar) convierte la zona **negra** en transparencia (`Alfa`), permitiendo ver el video o clip que se encuentra debajo [[01:32](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=92)].
# * **Desventaja:** Este método puede dejar rastros de color negro o bordes pixelados si no se ajusta con precisión [[01:57](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=117)].
#
# ### 2. Máscara Cargar Alfa (`Load Alpha Mask`)
#
# Este es un efecto más directo para usar una imagen o video como fuente de la máscara.
#
# * **Uso:** Aplica el efecto **Máscara Cargar Alfa** al clip que deseas recortar [[02:14](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=134)].
# * **Fuente:** En las propiedades del efecto, carga el archivo de imagen o gráfico (debe ser blanco y negro) que servirá como máscara (ej. un texto) [[02:22](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=142)].
# * **Función:** El efecto recorta el clip al que se aplica para que solo se vea la zona que corresponde al área de la máscara, dejando ver el video inferior a través del recorte [[02:32](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=152)].
# * **Ajustes:**
#     * **Umbral (`Threshold`):** Permite jugar con los niveles de gris del gráfico. Si la imagen original tiene un degradado de blanco a gris, el umbral define qué tan profunda se ve la transparencia. Al subirlo, se puede hacer desaparecer el texto gradualmente [[02:49](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=169)].
#     * **Suavidad del Borde (`Softness`):** Hace que el corte sea más o menos duro [[03:09](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=189)].
#     * **Invertir:** Intercambia la zona visible por la invisible [[03:26](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=206)].
#
# ### 3. Máscara Forma Alfa (`Alpha Shape Mask`)
#
# Esta herramienta permite crear rápidamente máscaras geométricas sin necesidad de importar un gráfico externo.
#
# * **Uso:** Aplica el efecto **Máscara Forma Alfa** [[03:37](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=217)].
# * **Función:** Permite seleccionar figuras geométricas (círculos, rectángulos, etc.) para que actúen como la máscara.
# * **Ajustes:** Puedes modificar la **posición**, **tamaño**, **rotación** y, fundamentalmente, la **suavidad del borde** [[03:41](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=221)]. Es simple, pero ahorra tiempo.
#
# ### 4. Máscara Rotoscopia (`Rotoscoping Mask`)
#
# Considerada la "madre de todas las máscaras", la rotoscopia permite dibujar y animar una máscara de forma libre en el tiempo.
#
# * **Uso:** Aplica el efecto **Máscara Rotoscopia** al clip [[04:22](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=262)].
# * **Dibujar la Máscara:** Dibuja la máscara con puntos siguiendo la silueta del objeto que deseas aislar o revelar (ej. la silueta de un pantalón) [[04:33](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=273)]. Cierra la máscara haciendo clic sobre el primer punto con el botón derecho del ratón [[04:40](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=280)].
# * **Invertir:** Por defecto, la máscara puede aparecer al revés (mostrando el interior en lugar del exterior). Simplemente activa la opción **Inversa** [[04:47](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=287)].
# * **Animación (Tracking):**
#     1.  Activa los **fotogramas clave** (`keyframes`) [[04:52](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=292)].
#     2.  Avanza la reproducción unos pocos fotogramas (con la flecha derecha del teclado, cada pulsación es un fotograma) [[05:15](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=315)].
#     3.  **Modifica** la posición de los puntos para que la máscara siga la silueta del objeto en el nuevo fotograma [[04:57](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=297)].
#     4.  Repite el proceso hasta que el objeto desaparezca de la escena [[05:03](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=303)]. Kdenlive interpolará el movimiento entre los fotogramas clave.
#
# > **Resultado:** La máscara se mueve con el objeto, revelando dinámicamente el clip de la pista inferior, lo que puede usarse para transiciones, revelar textos o cualquier efecto creativo [[05:43](http://www.youtube.com/watch?v=qRqu_iJHtU0&t=343)].
#
#
# http://googleusercontent.com/youtube_content/24

# %% [markdown]
# # Seguimos....

# %% [markdown]
# ## 10/12/2025
