# %% [markdown]
# ¡Excelente hallazgo! Este video del canal **Alejavi Rivera**, titulado *"¡La IA China 3 rompe con TODO Gratis y SIN Límites!"*, es una guía fundamental para conocer las herramientas chinas más avanzadas (de gigantes como Alibaba) que están compitiendo directamente con los modelos de pago occidentales.
#
# Aquí tienes un resumen detallado de las **3 plataformas** clave y los **12 casos de uso** prácticos que presenta:
#
# ---
#
# ## 🚀 Guía de Herramientas de IA China (Gratis e Ilimitadas)
#
# ### 1. Quen / One (Ecosistema de Alibaba)
#
# Es el plato fuerte del video por su capacidad de ofrecer modelos de código abierto con funciones pioneras.
#
# * **Edición de Imágenes (Chat Edit):** Permite subir una imagen y pedir cambios específicos mediante chat (ej. cambiar una palabra o un objeto) de forma gratuita e ilimitada si se desactiva la opción de créditos en los ajustes [[01:20](http://www.youtube.com/watch?v=QeFpHztmGqU&t=80), [02:11](http://www.youtube.com/watch?v=QeFpHztmGqU&t=131)].
# * **Audio a Video (Nuevo modelo 2.6):** Puedes subir un audio o música (máx. 30 seg) y la IA genera un video de hasta 15 segundos donde el entorno y los personajes se mueven al ritmo de la música, incluyendo sincronización labial avanzada [[03:03](http://www.youtube.com/watch?v=QeFpHztmGqU&t=183), [03:34](http://www.youtube.com/watch?v=QeFpHztmGqU&t=214)].
# * **Vídeos con Multipersonajes:** Permite seleccionar y combinar varios personajes predefinidos (ej. un Santa Claus y un Samurái) en una misma escena de video [[06:26](http://www.youtube.com/watch?v=QeFpHztmGqU&t=386), [06:44](http://www.youtube.com/watch?v=QeFpHztmGqU&t=404)].
# * **Clonación de Personajes (Avatar Realista):** Puedes "entrenar" a la IA con tu propia cara grabando un video corto mirando a diferentes puntos. Luego, puedes generarte a ti mismo en cualquier situación (ej. saltando de un avión) hablando en cualquier idioma [[07:15](http://www.youtube.com/watch?v=QeFpHztmGqU&t=435), [07:53](http://www.youtube.com/watch?v=QeFpHztmGqU&t=473)].
# * **Generación Rápida de Video:** A través de la interfaz de chat de Quen, se pueden generar videos realistas (como una rana motera) de forma casi instantánea, evitando las colas de espera de otras plataformas [[09:44](http://www.youtube.com/watch?v=QeFpHztmGqU&t=584), [10:03](http://www.youtube.com/watch?v=QeFpHztmGqU&t=603)].
#
# ### 2. Chat Z (Modelo GLM 4.7)
#
# Presentado como el mejor modelo de código abierto actual, superando a DeepSeek y compitiendo con GPT-4 o Gemini.
#
# * **Réplica de Photoshop (Image Layered):** Utilizando la API de Quen, el autor crea una aplicación web que divide cualquier imagen en capas (fondo, personas, edificios) de forma automática, permitiendo mover o editar elementos individuales [[11:27](http://www.youtube.com/watch?v=QeFpHztmGqU&t=687), [13:07](http://www.youtube.com/watch?v=QeFpHztmGqU&t=787)].
# * **Transformación de Mapas Mentales:** Permite subir un mapa mental (ej. de NotebookLM) y convertirlo en una interfaz HTML interactiva donde puedes clicar en nodos para ver definiciones y datos de popularidad [[14:34](http://www.youtube.com/watch?v=QeFpHztmGqU&t=874), [15:30](http://www.youtube.com/watch?v=QeFpHztmGqU&t=930)].
# * **Simuladores Full Stack:** Gracias a su nueva función "Full Stack", puede desarrollar proyectos completos con lógica interna (*backend*). El video muestra un **simulador de iPhone funcional** que incluye calculadora, navegador Safari, cámara conectada a la webcam y mapas [[16:16](http://www.youtube.com/watch?v=QeFpHztmGqU&t=976), [17:12](http://www.youtube.com/watch?v=QeFpHztmGqU&t=1032)].
# * **Creación de Juegos:** Capacidad para programar juegos funcionales (ej. un juego de esquivar objetos) desde cero [[18:21](http://www.youtube.com/watch?v=QeFpHztmGqU&t=1101)].
#
# ### 3. Perce (Plataforma sin restricciones)
#
# Una herramienta que destaca por no requerir registro, no tener marcas de agua y carecer de censura.
#
# * **Upscale de Imágenes:** Permite subir la calidad y resolución de imágenes pixeladas de forma ilimitada [[19:40](http://www.youtube.com/watch?v=QeFpHztmGqU&t=1180), [20:08](http://www.youtube.com/watch?v=QeFpHztmGqU&t=1208)].
# * **Imagen a Prompt:** Convierte cualquier imagen que te guste en un *prompt* técnico detallado para que puedas recrear el estilo o elementos en otras IAs [[20:30](http://www.youtube.com/watch?v=QeFpHztmGqU&t=1230), [21:04](http://www.youtube.com/watch?v=QeFpHztmGqU&t=1264)].
# * **Generación Sin Censura (Unsafe):** Permite crear imágenes de cualquier tipo (incluyendo desnudos artísticos o contenido restringido en otras IAs) con gran detalle y sin limitaciones de créditos [[19:23](http://www.youtube.com/watch?v=QeFpHztmGqU&t=1163), [21:25](http://www.youtube.com/watch?v=QeFpHztmGqU&t=1285)].
#
# ---
#
# **Cita del autor:** *"Estamos en un momento donde podemos crear prácticamente cualquier cosa... el objetivo y la constancia es quien decide el resultado"* [[23:12](http://www.youtube.com/watch?v=QeFpHztmGqU&t=1392)].
#
# **Enlaces:** El autor deja todas las herramientas mencionadas en la descripción de su video para que cualquiera pueda probarlas hoy mismo [[01:14](http://www.youtube.com/watch?v=QeFpHztmGqU&t=74)].
