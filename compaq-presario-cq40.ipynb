# %% [markdown]
# # gemini 3:
# dime que caracteristicas tendria que tener mi pc para trabajar bien con los editores de video, audio ,codigo, IAs, para generar contenido con IAs de forma rapida con grok y nano banana, compara con mis features: pol@debian:~$ df -h
# S.ficheros     Tamaño Usados  Disp Uso% Montado en
# udev             1,9G      0  1,9G   0% /dev
# tmpfs            383M   1,5M  381M   1% /run
# /dev/sda1        216G    52G  153G  26% /
# tmpfs            1,9G   129M  1,8G   7% /dev/shm
# /dev/loop1       128K   128K     0 100% /snap/bare/5
# /dev/loop0        74M    74M     0 100% /snap/core22/2193
# /dev/loop2        74M    74M     0 100% /snap/core22/2163
# /dev/loop3       517M   517M     0 100% /snap/gnome-42-2204/202
# /dev/loop5       517M   517M     0 100% /snap/gnome-42-2204/226
# /dev/loop6        51M    51M     0 100% /snap/snapd/25202
# /dev/loop7       166M   166M     0 100% /snap/mysql-workbench-community/13
# /dev/loop4        92M    92M     0 100% /snap/gtk-common-themes/1535
# /dev/loop8        51M    51M     0 100% /snap/snapd/25577
# tmpfs            4,0G    32M  4,0G   1% /tmp
# none             1,0M      0  1,0M   0% /run/credentials/getty@tty1.service
# tmpfs            383M   136K  383M   1% /run/user/1000
# none             1,0M      0  1,0M   0% /run/credentials/systemd-journald.service
# pol@debian:~$ free -h
#                total       usado       libre  compartido   búf/caché  disponible
# Mem:           3,7Gi       3,0Gi       214Mi       100Mi       879Mi       753Mi
# Inter:         3,9Gi       2,3Gi       1,6Gi
# pol@debian:~$ fastfetch
# zsh: command not found: fastfetch
# pol@debian:~$ neofetch
#        _,met$$$$$gg.          pol@debian
#     ,g$$$$$$$$$$$$$$$P.       ----------
#   ,g$$P"        """Y$$.".     OS: Debian GNU/Linux forky/sid x86_64
#  ,$$P'              `$$$.     Host: Hewlett-Packard 3607
# ',$$P       ,ggs.     `$$b:   Kernel: 6.17.8+deb14-amd64
# `d$$'     ,$P"'   .    $$$    Uptime: 3 hours, 53 mins
#  $$P      d$'     ,    $$P    Packages: 2316 (dpkg), 7 (flatpak), 6 (snap)
#  $$:      $$.   -    ,d$$'    Shell: zsh 5.9
#  $$;      Y$b._   _,d$P'      Resolution: 1280x800
#  Y$$.    `.`"Y$$$$P"'         DE: Xfce 4.20
#  `$$b      "-.__              WM: Xfwm4
#   `Y$$                        WM Theme: Default
#    `Y$$.                      Theme: Xfce [GTK2/3]
#      `$$b.                    Icons: Tango [GTK2/3]
#        `Y$$b.                 Terminal: x-terminal-emul
#           `"Y$b._             CPU: Pentium T4200 (2) @ 2.000GHz
#               `"""            GPU: Intel Mobile 4 Series Chipset
#                               Memory: 3079MiB / 3824MiB
#
#
#
#
# pol@debian:~$
